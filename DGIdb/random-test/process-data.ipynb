# %%
import pandas as pd

# %%
import os
from natsort import natsorted

directory = 'results/'

df = pd.DataFrame()
for file in natsorted(os.listdir(directory)):
    print(file)
    tdf = pd.read_excel(f'{directory}/{file}').drop(columns='Unnamed: 0',axis=1)
    df = pd.concat([df,tdf]).reset_index(drop=True)

df[0:5]
# Out:
# 20240325_trial_1-1.xlsx
# 20240325_trial_1-2.xlsx
# 20240325_trial_1-3.xlsx
# 20240325_trial_1-4.xlsx
# 20240325_trial_1-5.xlsx
# 20240325_trial_1-6.xlsx
# 20240325_trial_1-7.xlsx
# 20240325_trial_1-8.xlsx
# 20240325_trial_1-9.xlsx
# 20240325_trial_1-10.xlsx
#                          brand_name application_number  \
# 0                 ZOLPIDEM TARTRATE         ANDA077903
# 1                 dimethyl fumarate         ANDA210382
# 2               Amlodipine Besylate         ANDA077955
# 3                          Kalydeco          NDA203188
# 4  Dexmethylphenidate Hydrochloride         ANDA202842
#
#                                    adverse_reactions  \
# 0  6. ADVERSE REACTIONS Most commonly observed ad...
# 1  6 ADVERSE REACTIONS The following important ad...
# 2  6 ADVERSE REACTIONS Most common adverse reacti...
# 3  6 ADVERSE REACTIONS The following adverse reac...
# 4  6 ADVERSE REACTIONS The following are discusse...
#
#                                     clinical_studies  \
# 0  14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 1  14 CLINICAL STUDIES The efficacy and safety of...
# 2  14 CLINICAL STUDIES 14.1 Effects in Hypertensi...
# 3  14 CLINICAL STUDIES 14.1 Trials in Patients wi...
# 4  14 CLINICAL STUDIES 14.1 Pediatric Patients A ...
#
#                                indications_and_usage  \
# 0  1. INDICATIONS AND USAGE Zolpidem tartrate tab...
# 1  1 INDICATIONS AND USAGE Dimethyl fumarate dela...
# 2  1 INDICATIONS AND USAGE Amlodipine besylate, U...
# 3  1 INDICATIONS AND USAGE KALYDECO is indicated ...
# 4  1 INDICATIONS AND USAGE Dexmethylphenidate hyd...
#
#                                    contraindications  \
# 0  4. CONTRAINDICATIONS Known hypersensitivity to...
# 1  4 CONTRAINDICATIONS Dimethyl fumarate delayed-...
# 2  4 CONTRAINDICATIONS Known sensitivity to amlod...
# 3               4 CONTRAINDICATIONS None. None ( 4 )
# 4  4 CONTRAINDICATIONS Hypersensitivity to methyl...
#
#                                warnings_and_cautions warnings precautions  \
# 0  5. WARNINGS AND PRECAUTIONS • CNS depressant e...      NaN         NaN
# 1  5 WARNINGS AND PRECAUTIONS Anaphylaxis and ang...      NaN         NaN
# 2  5 WARNINGS AND PRECAUTIONS Symptomatic hypoten...      NaN         NaN
# 3  5 WARNINGS AND PRECAUTIONS Elevated transamina...      NaN         NaN
# 4  5 WARNINGS AND PRECAUTIONS Serious Cardiovascu...      NaN         NaN
#
#                                     pharmacokinetics purpose  \
# 0  12.3 Pharmacokinetics The pharmacokinetic prof...     NaN
# 1                                                NaN     NaN
# 2  12.3 Pharmacokinetics After oral administratio...     NaN
# 3  12.3 Pharmacokinetics The pharmacokinetics of ...     NaN
# 4  12.3 Pharmacokinetics Absorption Dexmethylphen...     NaN
#
#                                clinical_pharmacology active_ingredient  \
# 0  12. CLINICAL PHARMACOLOGY 12.1 Mechanism of Ac...               NaN
# 1  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 2  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 3  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 4  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
#
#   stop_use                                      boxed_warning  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3      NaN                                                NaN
# 4      NaN  WARNING: ABUSE AND DEPENDENCE CNS stimulants, ...
#
#                                     pharmacodynamics pharmacogenomics  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2  12.2 Pharmacodynamics Hemodynamics: Following ...              NaN
# 3  12.2 Pharmacodynamics Sweat Chloride Evaluatio...              NaN
# 4  12.2 Pharmacodynamics Dexmethylphenidate is th...              NaN
#
#                                          outcome_raw
# 0   {"result": {\n"outcome": {\n"metric": "Sleep ...
# 1  ERROR: The prompt size exceeds the context win...
# 2  ERROR: The prompt size exceeds the context win...
# 3  ERROR: The prompt size exceeds the context win...
# 4   {"result": {\n"outcome": {\n"metric": "DSM-IV...

# %%
# ERROR: The prompt size exceeds the context window size and cannot be processed.
df = df[df['outcome_raw'].str.contains('ERROR: The prompt size exceeds the context window size and cannot be processed.')==False].reset_index(drop=True)
df = df[df['brand_name'].isnull()==False].reset_index(drop=True)
df = df[df['application_number'].isnull()==False].reset_index(drop=True)


print(len(df))
df[0:5]
# Out:
# 254
#                          brand_name application_number  \
# 0                 ZOLPIDEM TARTRATE         ANDA077903
# 1  Dexmethylphenidate Hydrochloride         ANDA202842
# 2                         Mupirocin         ANDA065170
# 3              Diclofenac Potassium         ANDA213875
# 4          Lurasidone hydrochloride         ANDA208047
#
#                                    adverse_reactions  \
# 0  6. ADVERSE REACTIONS Most commonly observed ad...
# 1  6 ADVERSE REACTIONS The following are discusse...
# 2  6 ADVERSE REACTIONS The following adverse reac...
# 3  6 ADVERSE REACTIONS The following adverse reac...
# 4  6 ADVERSE REACTIONS The following adverse reac...
#
#                                     clinical_studies  \
# 0  14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 1  14 CLINICAL STUDIES 14.1 Pediatric Patients A ...
# 2  14 CLINICAL STUDIES The efficacy of topical mu...
# 3  14 CLINICAL STUDIES The efficacy of diclofenac...
# 4  14 CLINICAL STUDIES 14.2 Depressive Episodes A...
#
#                                indications_and_usage  \
# 0  1. INDICATIONS AND USAGE Zolpidem tartrate tab...
# 1  1 INDICATIONS AND USAGE Dexmethylphenidate hyd...
# 2  1 INDICATIONS AND USAGE Mupirocin Ointment USP...
# 3  1 INDICATIONS AND USAGE Diclofenac potassium c...
# 4  1 INDICATIONS AND USAGE Lurasidone hydrochlori...
#
#                                    contraindications  \
# 0  4. CONTRAINDICATIONS Known hypersensitivity to...
# 1  4 CONTRAINDICATIONS Hypersensitivity to methyl...
# 2  4 CONTRAINDICATIONS Mupirocin ointment is cont...
# 3  4 CONTRAINDICATIONS Diclofenac potassium capsu...
# 4  4 CONTRAINDICATIONS Known hypersensitivity to ...
#
#                                warnings_and_cautions warnings precautions  \
# 0  5. WARNINGS AND PRECAUTIONS • CNS depressant e...      NaN         NaN
# 1  5 WARNINGS AND PRECAUTIONS Serious Cardiovascu...      NaN         NaN
# 2  5 WARNINGS AND PRECAUTIONS Severe Allergic Rea...      NaN         NaN
# 3  5 WARNINGS AND PRECAUTIONS Hepatotoxicity : In...      NaN         NaN
# 4  5 WARNINGS AND PRECAUTIONS Cerebrovascular Adv...      NaN         NaN
#
#                                     pharmacokinetics purpose  \
# 0  12.3 Pharmacokinetics The pharmacokinetic prof...     NaN
# 1  12.3 Pharmacokinetics Absorption Dexmethylphen...     NaN
# 2  12.3 Pharmacokinetics Absorption Application o...     NaN
# 3  12.3 Pharmacokinetics The pharmacokinetics of ...     NaN
# 4                                                NaN     NaN
#
#                                clinical_pharmacology active_ingredient  \
# 0  12. CLINICAL PHARMACOLOGY 12.1 Mechanism of Ac...               NaN
# 1  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 2  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 3  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 4  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
#
#   stop_use                                      boxed_warning  \
# 0      NaN                                                NaN
# 1      NaN  WARNING: ABUSE AND DEPENDENCE CNS stimulants, ...
# 2      NaN                                                NaN
# 3      NaN  WARNING: RISK OF SERIOUS CARDIOVASCULAR AND GA...
# 4      NaN  WARNING: INCREASED MORTALITY IN ELDERLY PATIEN...
#
#                                     pharmacodynamics pharmacogenomics  \
# 0                                                NaN              NaN
# 1  12.2 Pharmacodynamics Dexmethylphenidate is th...              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#                                          outcome_raw
# 0   {"result": {\n"outcome": {\n"metric": "Sleep ...
# 1   {"result": {\n"outcome": {\n"metric": "DSM-IV...
# 2   {\n"result": {\n"outcome": {\n"metric": "clin...
# 3   {\n"result": {\n"outcome": {\n"metric": "Pain...
# 4   {"result": {\n    "outcome": {\n        "metr...

# %%
import re

def extract_metrics(text):
    """
    Splits the input text at every occurrence of the word "metric" followed by
    quotes and grabs the value wrapped in quotes immediately after it.

    Parameters:
    - text (str): The input text to search through.

    Returns:
    - list of str: A list containing the values found immediately after "metric".
    """
    # Adjusting our lens to focus on "metric": "value" patterns.
    # The pattern looks for the word "metric" followed by any amount of whitespace,
    # then a colon, possibly some more whitespace, and finally a quoted value.
    pattern = r'"metric"\s*:\s*"([^"]*)"'

    # Our detective work uses 'findall' to collect all matching quoted values.
    values = re.findall(pattern, text)

    return values

def extract_values(text):
    """
    Splits the input text at every occurrence of the word "metric" followed by
    quotes and grabs the value wrapped in quotes immediately after it.

    Parameters:
    - text (str): The input text to search through.

    Returns:
    - list of str: A list containing the values found immediately after "metric".
    """
    # Adjusting our lens to focus on "metric": "value" patterns.
    # The pattern looks for the word "metric" followed by any amount of whitespace,
    # then a colon, possibly some more whitespace, and finally a quoted value.
    pattern = r'"value"\s*:\s*"([^"]*)"'

    # Our detective work uses 'findall' to collect all matching quoted values.
    values = re.findall(pattern, text)

    return values

def extract_descriptors(text):
    """
    Splits the input text at every occurrence of the word "metric" followed by
    quotes and grabs the value wrapped in quotes immediately after it.

    Parameters:
    - text (str): The input text to search through.

    Returns:
    - list of str: A list containing the values found immediately after "metric".
    """
    # Adjusting our lens to focus on "metric": "value" patterns.
    # The pattern looks for the word "metric" followed by any amount of whitespace,
    # then a colon, possibly some more whitespace, and finally a quoted value.
    pattern = r'"descriptors"\s*:\s*"([^"]*)"'

    # Our detective work uses 'findall' to collect all matching quoted values.
    values = re.findall(pattern, text)

    return values

def equalize_list_lengths(list1, list2):
    """
    Checks the lengths of two lists and, if they differ, appends "N/A" to the shorter
    one until both lists have equal lengths.

    Parameters:
    - list1, list2 (list): The lists to be equalized.

    Modifies the input lists in place.
    """
    # First, let's see who's the shorter party here.
    length_difference = len(list1) - len(list2)

    # If list1 is the shorter one.
    if length_difference < 0:
        for _ in range(abs(length_difference)):
            list1.append("N/A")
    # Else if list2 is the shorter one.
    elif length_difference > 0:
        for _ in range(length_difference):
            list2.append("N/A")
    # If they're already equal, they both leave the courtroom with dignity.

# %%
df['outcome_raw'][250]
# Out:
# ' {\n  "result": {\n    "outcome": {\n      "metric": "primary treatment outcomes",\n      "value": [\n        {\n          "descriptors": "reduced serum TG levels"\n        },\n        {\n          "descriptors": "reduced non-HDL-C, circulating remnant lipoprotein levels, total-C, LDL-C and HDL-C"\n        }\n      ]\n    }\n  }\n}'

# %%
# Datafame Format 1: (combined statements)
statements = []
brands = []
apps = []
texts = []

position = 0
for outcome in df['outcome_raw']:

    if position == 250: # TODO: handle no valid value extracted
        continue

    brand_name = df['brand_name'][position]
    app_no = df['application_number'][position]
    original_text = df['clinical_studies'][position]

    metrics = extract_metrics(outcome)
    values = extract_values(outcome)
    descriptors = extract_descriptors(outcome)

    equalize_list_lengths(metrics, values)
    equalize_list_lengths(metrics, descriptors)

    for i in range(len(metrics)):
        statement = f'{metrics[i]}: {values[i]} ({descriptors[i]})'

        statements.append(statement)
        brands.append(brand_name)
        apps.append(app_no)
        texts.append(original_text)

    position += 1

data_format1 = pd.DataFrame().assign(brand_name=brands,application=apps,original_text=texts,statement=statements)
data_format1
# Out:
#                     brand_name application  \
# 0            ZOLPIDEM TARTRATE  ANDA077903
# 1            ZOLPIDEM TARTRATE  ANDA077903
# 2            ZOLPIDEM TARTRATE  ANDA077903
# 3            ZOLPIDEM TARTRATE  ANDA077903
# 4                    Mupirocin  ANDA065170
# ..                         ...         ...
# 445                    Winlevi   NDA213433
# 446               Escitalopram  ANDA202389
# 447                 Fluoxetine  ANDA206937
# 448                 Fluoxetine  ANDA206937
# 449  Dicyclomine Hydrochloride  ANDA085082
#
#                                          original_text  \
# 0    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 1    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 2    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 3    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 4    14 CLINICAL STUDIES The efficacy of topical mu...
# ..                                                 ...
# 445  14 CLINICAL STUDIES The safety and efficacy of...
# 446  14 CLINICAL STUDIES 14.1 Major Depressive Diso...
# 447  14 CLINICAL STUDIES 14.1 Premenstrual Dysphori...
# 448  14 CLINICAL STUDIES 14.1 Premenstrual Dysphori...
# 449  14 CLINICAL STUDIES In controlled clinical tri...
#
#                                              statement
# 0    Sleep latency: Reduced (Objective measure of t...
# 1    Sleep duration: Increased (Objective measure o...
# 2    Number of awakenings: Reduced (Subjective meas...
# 3                        Sleep quality: Improved (N/A)
# 4    clinical efficacy rate: 71% (adults and pediat...
# ..                                                 ...
# 445  Non-inflammatory Lesions Mean Percent Reductio...
# 446  Primary treatment outcomes: Change from baseli...
# 447  efficacy: significantly more effective than pl...
# 448  efficacy: significantly more effective than pl...
# 449  Clinical Response: 82% (Patients treated for f...
#
# [450 rows x 4 columns]

# %%
# Datafame Format 2: (separated metrics, values, descriptors)
metric_list = []
value_list = []
descriptor_list = []

texts = []
brands = []
apps = []

position = 0
for outcome in df['outcome_raw']:

    if position == 250:
        continue

    brand_name = df['brand_name'][position]
    app_no = df['application_number'][position]
    original_text = df['clinical_studies'][position]

    metrics = extract_metrics(outcome)
    values = extract_values(outcome)
    descriptors = extract_descriptors(outcome)

    equalize_list_lengths(metrics, values)
    equalize_list_lengths(metrics, descriptors)

    for i in range(len(metrics)):
        metric_list.append(metrics[i])
        value_list.append(values[i])
        descriptor_list.append(descriptors[i])

        texts.append(original_text)
        brands.append(brand_name)
        apps.append(app_no)

    position += 1

data_format2 = pd.DataFrame().assign(brand_name=brands,application=apps,original_text=texts,metrics=metric_list,values=value_list,descriptors=descriptor_list)
data_format2
# Out:
#                     brand_name application  \
# 0            ZOLPIDEM TARTRATE  ANDA077903
# 1            ZOLPIDEM TARTRATE  ANDA077903
# 2            ZOLPIDEM TARTRATE  ANDA077903
# 3            ZOLPIDEM TARTRATE  ANDA077903
# 4                    Mupirocin  ANDA065170
# ..                         ...         ...
# 445                    Winlevi   NDA213433
# 446               Escitalopram  ANDA202389
# 447                 Fluoxetine  ANDA206937
# 448                 Fluoxetine  ANDA206937
# 449  Dicyclomine Hydrochloride  ANDA085082
#
#                                          original_text  \
# 0    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 1    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 2    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 3    14. CLINICAL STUDIES 14.1 Transient Insomnia N...
# 4    14 CLINICAL STUDIES The efficacy of topical mu...
# ..                                                 ...
# 445  14 CLINICAL STUDIES The safety and efficacy of...
# 446  14 CLINICAL STUDIES 14.1 Major Depressive Diso...
# 447  14 CLINICAL STUDIES 14.1 Premenstrual Dysphori...
# 448  14 CLINICAL STUDIES 14.1 Premenstrual Dysphori...
# 449  14 CLINICAL STUDIES In controlled clinical tri...
#
#                                              metrics  \
# 0                                      Sleep latency
# 1                                     Sleep duration
# 2                               Number of awakenings
# 3                                      Sleep quality
# 4                             clinical efficacy rate
# ..                                               ...
# 445  Non-inflammatory Lesions Mean Percent Reduction
# 446                       Primary treatment outcomes
# 447                                         efficacy
# 448                                         efficacy
# 449                                Clinical Response
#
#                                                 values  \
# 0                                              Reduced
# 1                                            Increased
# 2                                              Reduced
# 3                                             Improved
# 4                                                  71%
# ..                                                 ...
# 445                                                N/A
# 446  Change from baseline to endpoint in the Childr...
# 447          significantly more effective than placebo
# 448          significantly more effective than placebo
# 449                                                82%
#
#                                            descriptors
# 0    Objective measure of time taken to fall asleep...
# 1    Objective measure of total amount of sleep obt...
# 2    Subjective measure of number of times a person...
# 3                                                  N/A
# 4    adults and pediatric subjects included, random...
# ..                                                 ...
# 445                                                N/A
# 446  Efficacy of escitalopram oxalate as an acute t...
# 447  as measured by the DRSP total score in an inte...
# 448                                                N/A
# 449  Patients treated for functional bowel/irritabl...
#
# [450 rows x 6 columns]

# %%
data_format1.to_excel('20240325_trial1_results.xlsx')
