# %%
import pandas as pd

# %% [markdown]
# ## Filter for Valid Data

# %%
import os
from natsort import natsorted

directory = 'results/run2'

df = pd.DataFrame()
for file in natsorted(os.listdir(directory)):
    print(file)
    tdf = pd.read_excel(f'{directory}/{file}').drop(columns='Unnamed: 0',axis=1)
    df = pd.concat([df,tdf]).reset_index(drop=True)

df[0:5]
# Out:
# 20240320_clinical_trials_test_2-1.xlsx
# 20240320_clinical_trials_test_2-2.xlsx
# 20240320_clinical_trials_test_2-3.xlsx
# 20240320_clinical_trials_test_2-4.xlsx
# 20240320_clinical_trials_test_2-5.xlsx
# 20240322_clinical_trials_test_2-6.xlsx
# 20240322_clinical_trials_test_2-7.xlsx
# 20240322_clinical_trials_test_2-8.xlsx
# 20240322_clinical_trials_test_2-9.xlsx
# 20240322_clinical_trials_test_2-10.xlsx
#                               brand_name application_number  \
# 0  AMOXICILLIN AND CLAVULANATE POTASSIUM         ANDA065117
# 1                              ARTHROTEC          NDA020607
# 2  Amoxicillin and Clavulanate Potassium         ANDA091569
# 3                          ADVAIR DISKUS          NDA021077
# 4               Ampicillin and Sulbactam         ANDA090579
#
#                                    adverse_reactions  \
# 0  ADVERSE REACTIONS SECTION The following are di...
# 1  6 ADVERSE REACTIONS The following adverse reac...
# 2  6 ADVERSE REACTIONS The following are discusse...
# 3  6 ADVERSE REACTIONS Use of LABA may result in ...
# 4  ADVERSE REACTIONS Adult Patients Ampicillin an...
#
#                                     clinical_studies  \
# 0  CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 1  14 CLINICAL STUDIES Osteoarthritis Diclofenac ...
# 2  14 CLINICAL STUDIES 14.1 Lower Respiratory Tra...
# 3  14 CLINICAL STUDIES 14.1 Asthma Adult and Adol...
# 4  CLINICAL STUDIES Skin and Skin Structure Infec...
#
#                                indications_and_usage  \
# 0  INDICATIONS & USAGE SECTION To reduce the deve...
# 1  1 INDICATIONS AND USAGE ARTHROTEC is indicated...
# 2  1 INDICATIONS AND USAGE Amoxicillin and clavul...
# 3  1 INDICATIONS AND USAGE ADVAIR DISKUS is a com...
# 4  INDICATIONS AND USAGE Ampicillin and sulbactam...
#
#                                    contraindications  \
# 0  CONTRAINDICATIONS SECTION Amoxicillinfor oral ...
# 1  4 CONTRAINDICATIONS ARTHROTEC is contraindicat...
# 2  4 CONTRAINDICATIONS History of a serious hyper...
# 3  4 CONTRAINDICATIONS The use of ADVAIR DISKUS i...
# 4  CONTRAINDICATIONS The use of ampicillin and su...
#
#                                warnings_and_cautions  \
# 0  WARNINGS AND PRECAUTIONS SECTION 5.1 Anaphylac...
# 1  5 WARNINGS AND PRECAUTIONS • Embryo-Fetal Toxi...
# 2  5 WARNINGS AND PRECAUTIONS Serious (including ...
# 3  5 WARNINGS AND PRECAUTIONS • LABA monotherapy ...
# 4                                                NaN
#
#                                             warnings  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  WARNINGS Hypersensitivity Serious and occasion...
#
#                                          precautions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  PRECAUTIONS General A high percentage of patie...
#
#                                     pharmacokinetics purpose  \
# 0                                                NaN     NaN
# 1  12.3 Pharmacokinetics General Pharmacokinetic ...     NaN
# 2  12.3 Pharmacokinetics Mean amoxicillin and cla...     NaN
# 3  12.3 Pharmacokinetics Absorption Fluticasone P...     NaN
# 4                                                NaN     NaN
#
#                                clinical_pharmacology active_ingredient  \
# 0  CLINICAL PHARMACOLOGY SECTION 12.1 Mechanism o...               NaN
# 1  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 2  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 3  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 4  CLINICAL PHARMACOLOGY General Immediately afte...               NaN
#
#   stop_use                                      boxed_warning  \
# 0      NaN                                                NaN
# 1      NaN  WARNING: RISK OF UTERINE RUPTURE, ABORTION, PR...
# 2      NaN                                                NaN
# 3      NaN                                                NaN
# 4      NaN                                                NaN
#
#                                     pharmacodynamics pharmacogenomics  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3  12.2 Pharmacodynamics ADVAIR DISKUS Healthy Su...              NaN
# 4                                                NaN              NaN
#
#                                          outcome_raw outcome_json
# 0   {\n"result": {\n"outcome": {\n"metric": "H. p...         None
# 1   {"result": {\n"outcome": {\n"metric": "Gastri...         None
# 2   {"result": {\n"outcome": {\n"metric": "Bacter...         None
# 3  ERROR: The prompt size exceeds the context win...         None
# 4   {"result": {\n"outcome": {\n"metric": "Clinic...         None

# %%
# ERROR: The prompt size exceeds the context window size and cannot be processed.
df = df[df['outcome_raw'].str.contains('ERROR: The prompt size exceeds the context window size and cannot be processed.')==False].reset_index(drop=True)
df = df[df['brand_name'].isnull()==False]
df = df[df['application_number'].isnull()==False]


print(len(df))
df[0:5]
# Out:
# 166
#                               brand_name application_number  \
# 0  AMOXICILLIN AND CLAVULANATE POTASSIUM         ANDA065117
# 1                              ARTHROTEC          NDA020607
# 2  Amoxicillin and Clavulanate Potassium         ANDA091569
# 3               Ampicillin and Sulbactam         ANDA090579
# 4                               LUMOXITI          BLA761104
#
#                                    adverse_reactions  \
# 0  ADVERSE REACTIONS SECTION The following are di...
# 1  6 ADVERSE REACTIONS The following adverse reac...
# 2  6 ADVERSE REACTIONS The following are discusse...
# 3  ADVERSE REACTIONS Adult Patients Ampicillin an...
# 4  6 ADVERSE REACTIONS The following adverse reac...
#
#                                     clinical_studies  \
# 0  CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 1  14 CLINICAL STUDIES Osteoarthritis Diclofenac ...
# 2  14 CLINICAL STUDIES 14.1 Lower Respiratory Tra...
# 3  CLINICAL STUDIES Skin and Skin Structure Infec...
# 4  14 CLINICAL STUDIES The efficacy of LUMOXITI w...
#
#                                indications_and_usage  \
# 0  INDICATIONS & USAGE SECTION To reduce the deve...
# 1  1 INDICATIONS AND USAGE ARTHROTEC is indicated...
# 2  1 INDICATIONS AND USAGE Amoxicillin and clavul...
# 3  INDICATIONS AND USAGE Ampicillin and sulbactam...
# 4  1 INDICATIONS AND USAGE LUMOXITI is indicated ...
#
#                                    contraindications  \
# 0  CONTRAINDICATIONS SECTION Amoxicillinfor oral ...
# 1  4 CONTRAINDICATIONS ARTHROTEC is contraindicat...
# 2  4 CONTRAINDICATIONS History of a serious hyper...
# 3  CONTRAINDICATIONS The use of ampicillin and su...
# 4                4 CONTRAINDICATIONS None. None. (4)
#
#                                warnings_and_cautions  \
# 0  WARNINGS AND PRECAUTIONS SECTION 5.1 Anaphylac...
# 1  5 WARNINGS AND PRECAUTIONS • Embryo-Fetal Toxi...
# 2  5 WARNINGS AND PRECAUTIONS Serious (including ...
# 3                                                NaN
# 4  5 WARNINGS AND PRECAUTIONS • Renal Toxicity: M...
#
#                                             warnings  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  WARNINGS Hypersensitivity Serious and occasion...
# 4                                                NaN
#
#                                          precautions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  PRECAUTIONS General A high percentage of patie...
# 4                                                NaN
#
#                                     pharmacokinetics purpose  \
# 0                                                NaN     NaN
# 1  12.3 Pharmacokinetics General Pharmacokinetic ...     NaN
# 2  12.3 Pharmacokinetics Mean amoxicillin and cla...     NaN
# 3                                                NaN     NaN
# 4  12.3 Pharmacokinetics The pharmacokinetics (PK...     NaN
#
#                                clinical_pharmacology active_ingredient  \
# 0  CLINICAL PHARMACOLOGY SECTION 12.1 Mechanism o...               NaN
# 1  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 2  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 3  CLINICAL PHARMACOLOGY General Immediately afte...               NaN
# 4  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
#
#   stop_use                                      boxed_warning  \
# 0      NaN                                                NaN
# 1      NaN  WARNING: RISK OF UTERINE RUPTURE, ABORTION, PR...
# 2      NaN                                                NaN
# 3      NaN                                                NaN
# 4      NaN  WARNING: CAPILLARY LEAK SYNDROME and HEMOLYTIC...
#
#                                     pharmacodynamics pharmacogenomics  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  12.2 Pharmacodynamics The presence of moxetumo...              NaN
#
#                                          outcome_raw outcome_json
# 0   {\n"result": {\n"outcome": {\n"metric": "H. p...         None
# 1   {"result": {\n"outcome": {\n"metric": "Gastri...         None
# 2   {"result": {\n"outcome": {\n"metric": "Bacter...         None
# 3   {"result": {\n"outcome": {\n"metric": "Clinic...         None
# 4   {"result": {\n"outcome": {\n"metric": "durabl...         None

# %%
# Out:
#     brand_name application_number  \
# 27         NaN                NaN
# 31         NaN                NaN
# 33         NaN                NaN
# 35         NaN                NaN
# 36         NaN                NaN
# ..         ...                ...
# 237        NaN                NaN
# 239        NaN                NaN
# 240        NaN                NaN
# 241        NaN                NaN
# 244        NaN                NaN
#
#                                      adverse_reactions  \
# 27   6 ADVERSE REACTIONS Major Depressive Disorder ...
# 31   6 ADVERSE REACTIONS Most Common Adverse Reacti...
# 33   6 ADVERSE REACTIONS The most common adverse re...
# 35   6 ADVERSE REACTIONS The following serious adve...
# 36   6 ADVERSE REACTIONS The following adverse reac...
# ..                                                 ...
# 237  6 ADVERSE REACTIONS The pattern of adverse eff...
# 239  ADVERSE REACTIONS The following have been repo...
# 240  ADVERSE REACTIONS Adverse reactions associated...
# 241  6 ADVERSE REACTIONS The following serious adve...
# 244  6 ADVERSE REACTIONS Most common adverse reacti...
#
#                                       clinical_studies  \
# 27   14 CLINICAL STUDIES 14.1 Major Depressive Diso...
# 31   14 CLINICAL STUDIES 14.1 Hypertension In a dou...
# 33   14 CLINICAL STUDIES In a 12-month, multicenter...
# 35   14 CLINICAL STUDIES 14.3 Hypertriglyceridemia ...
# 36   14 CLINICAL STUDIES The evidence for the effic...
# ..                                                 ...
# 237  14 CLINICAL STUDIES In controlled clinical tri...
# 239  Clinical studies In a series of small short-te...
# 240  CLINICAL STUDIES In patients with chronic asth...
# 241  14 CLINICAL STUDIES 14.1 Migraine In controlle...
# 244  14 CLINICAL STUDIES Olmesartan medoxomil and h...
#
#                                  indications_and_usage  \
# 27   1 INDICATIONS AND USAGE Venlafaxine hydrochlor...
# 31   1 INDICATIONS AND USAGE Metoprolol succinate e...
# 33   1 INDICATIONS AND USAGE Fayosim is an estrogen...
# 35   1 INDICATIONS AND USAGE Pediatric use informat...
# 36   1 INDICATIONS AND USAGE Ephedrine Sulfate Inje...
# ..                                                 ...
# 237  1 INDICATIONS AND USAGE Dicyclomine hydrochlor...
# 239  INDICATIONS AND USAGE Cytotec (misoprostol) is...
# 240  INDICATIONS AND USAGE Theophylline is indicate...
# 241  1 INDICATIONS AND USAGE Sumatriptan injection ...
# 244  1 INDICATIONS AND USAGE Olmesartan medoxomil a...
#
#                                      contraindications  \
# 27   4 CONTRAINDICATIONS Serotonin Syndrome and MAO...
# 31   4 CONTRAINDICATIONS Known hypersensitivity to ...
# 33   4 CONTRAINDICATIONS A high risk of arterial or...
# 35   4 CONTRAINDICATIONS Rosuvastatin tablets are c...
# 36                 4 CONTRAINDICATIONS None None ( 4 )
# ..                                                 ...
# 237  4 CONTRAINDICATIONS Dicyclomine hydrochloride ...
# 239  CONTRAINDICATIONS See boxed WARNINGS . Cytotec...
# 240  CONTRAINDICATIONS Theophylline (anhydrous) ext...
# 241  4 CONTRAINDICATIONS Sumatriptan injection is c...
# 244  4 CONTRAINDICATIONS Hypersensitivity to any co...
#
#                                  warnings_and_cautions  \
# 27   5 WARNINGS AND PRECAUTIONS Serotonin Syndrome:...
# 31   5 WARNINGS AND PRECAUTIONS Abrupt cessation ma...
# 33   5 WARNINGS AND PRECAUTIONS Vascular risks: Sto...
# 35   5 WARNINGS AND PRECAUTIONS Skeletal muscle eff...
# 36   5 WARNINGS AND PRECAUTIONS Pressor Effects wit...
# ..                                                 ...
# 237  5 WARNINGS AND PRECAUTIONS Cardiovascular cond...
# 239                                                NaN
# 240                                                NaN
# 241  5 WARNINGS AND PRECAUTIONS Myocardial ischemia...
# 244  5 WARNINGS AND PRECAUTIONS Hypotension: Correc...
#
#                                               warnings  \
# 27                                                 NaN
# 31                                                 NaN
# 33                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# ..                                                 ...
# 237                                                NaN
# 239  WARNINGS See boxed WARNINGS . For hospital use...
# 240  WARNINGS Concurrent Illness Theophylline shoul...
# 241                                                NaN
# 244                                                NaN
#
#                                            precautions  \
# 27                                                 NaN
# 31                                                 NaN
# 33                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# ..                                                 ...
# 237                                                NaN
# 239  PRECAUTIONS Caution should be employed when ad...
# 240  PRECAUTIONS General Careful consideration of t...
# 241                                                NaN
# 244                                                NaN
#
#                                       pharmacokinetics purpose  \
# 27   12.3 Pharmacokinetics Steady-state concentrati...     NaN
# 31   12.3 Pharmacokinetics Absorption The peak plas...     NaN
# 33   12.3 Pharmacokinetics Absorption Ethinyl estra...     NaN
# 35   12.3 Pharmacokinetics Absorption In clinical p...     NaN
# 36   12.3 Pharmacokinetics Publications studying ph...     NaN
# ..                                                 ...     ...
# 237  12.3 Pharmacokinetics Absorption and Distribut...     NaN
# 239  Pharmacokinetics Misoprostol is extensively ab...     NaN
# 240  Pharmacokinetics Overview Theophylline is rapi...     NaN
# 241  12.3 Pharmacokinetics Absorption The bioavaila...     NaN
# 244                                                NaN     NaN
#
#                                  clinical_pharmacology active_ingredient  \
# 27   12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 31   12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 33   12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 35   12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 36   12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# ..                                                 ...               ...
# 237  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 239  CLINICAL PHARMACOLOGY Pharmacokinetics Misopro...               NaN
# 240  CLINICAL PHARMACOLOGY Mechanism of Action Theo...               NaN
# 241  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
# 244  12 CLINICAL PHARMACOLOGY 12.1 Mechanism of Act...               NaN
#
#     stop_use                                      boxed_warning  \
# 27       NaN  WARNING: SUICIDALITY AND ANTIDEPRESSANT DRUGS ...
# 31       NaN                                                NaN
# 33       NaN  WARNING: CIGARETTE SMOKING AND SERIOUS CARDIOV...
# 35       NaN                                                NaN
# 36       NaN                                                NaN
# ..       ...                                                ...
# 237      NaN                                                NaN
# 239      NaN  WARNINGS CYTOTEC (MISOPROSTOL) ADMINISTRATION ...
# 240      NaN                                                NaN
# 241      NaN                                                NaN
# 244      NaN  WARNING FETAL TOXICITY W ARN ING: FETAL TOXICI...
#
#                                       pharmacodynamics  \
# 27   12.2 Pharmacodynamics Venlafaxine and its acti...
# 31   12.2 Pharmacodynamics Clinical pharmacology st...
# 33   12.2 Pharmacodynamics No pharmacodynamic studi...
# 35   12.2 Pharmacodynamics Rosuvastatin dose depend...
# 36   12.2 Pharmacodynamics Ephedrine stimulates hea...
# ..                                                 ...
# 237  12.2 Pharmacodynamics Dicyclomine hydrochlorid...
# 239  Pharmacodynamics Misoprostol has both antisecr...
# 240                                                NaN
# 241  12.2 Pharmacodynamics Blood Pressure Significa...
# 244                                                NaN
#
#                                       pharmacogenomics  \
# 27                                                 NaN
# 31                                                 NaN
# 33                                                 NaN
# 35   12.5 Pharmacogenomics Disposition of HMG-CoA r...
# 36                                                 NaN
# ..                                                 ...
# 237                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
# 244                                                NaN
#
#                                            outcome_raw outcome_json
# 27    {\n"result": {\n"outcome": {\n"metric": "effi...         None
# 31    {"result": {\n"outcome": {\n"metric": "blood ...         None
# 33    {"result": {\n"outcome": {\n"metric": "Pregna...         None
# 35    {"result": {\n"outcome": {\n"metric": "Primar...         None
# 36    {\n"result": {\n"outcome": {\n"metric": "bloo...         None
# ..                                                 ...          ...
# 237   {\n"result": {\n"outcome": {\n"metric": "clin...         None
# 239   {\n"result": {\n"outcome": {\n"metric": "NSAI...         None
# 240   {\n"result": {\n"outcome": {\n"metric": "symp...         None
# 241   {"result": {\n"outcome": {\n"metric": "relief...         None
# 244   {"result": {\n"outcome": {\n"metric": "blood ...         None
#
# [79 rows x 19 columns]

# %% [markdown]
# ## Break-up 'JSON'

# %%
import re

def extract_metrics(text):
    """
    Splits the input text at every occurrence of the word "metric" followed by
    quotes and grabs the value wrapped in quotes immediately after it.

    Parameters:
    - text (str): The input text to search through.

    Returns:
    - list of str: A list containing the values found immediately after "metric".
    """
    # Adjusting our lens to focus on "metric": "value" patterns.
    # The pattern looks for the word "metric" followed by any amount of whitespace,
    # then a colon, possibly some more whitespace, and finally a quoted value.
    pattern = r'"metric"\s*:\s*"([^"]*)"'

    # Our detective work uses 'findall' to collect all matching quoted values.
    values = re.findall(pattern, text)

    return values

def extract_values(text):
    """
    Splits the input text at every occurrence of the word "metric" followed by
    quotes and grabs the value wrapped in quotes immediately after it.

    Parameters:
    - text (str): The input text to search through.

    Returns:
    - list of str: A list containing the values found immediately after "metric".
    """
    # Adjusting our lens to focus on "metric": "value" patterns.
    # The pattern looks for the word "metric" followed by any amount of whitespace,
    # then a colon, possibly some more whitespace, and finally a quoted value.
    pattern = r'"value"\s*:\s*"([^"]*)"'

    # Our detective work uses 'findall' to collect all matching quoted values.
    values = re.findall(pattern, text)

    return values

def extract_descriptors(text):
    """
    Splits the input text at every occurrence of the word "metric" followed by
    quotes and grabs the value wrapped in quotes immediately after it.

    Parameters:
    - text (str): The input text to search through.

    Returns:
    - list of str: A list containing the values found immediately after "metric".
    """
    # Adjusting our lens to focus on "metric": "value" patterns.
    # The pattern looks for the word "metric" followed by any amount of whitespace,
    # then a colon, possibly some more whitespace, and finally a quoted value.
    pattern = r'"descriptors"\s*:\s*"([^"]*)"'

    # Our detective work uses 'findall' to collect all matching quoted values.
    values = re.findall(pattern, text)

    return values

def equalize_list_lengths(list1, list2):
    """
    Checks the lengths of two lists and, if they differ, appends "N/A" to the shorter
    one until both lists have equal lengths.

    Parameters:
    - list1, list2 (list): The lists to be equalized.

    Modifies the input lists in place.
    """
    # First, let's see who's the shorter party here.
    length_difference = len(list1) - len(list2)

    # If list1 is the shorter one.
    if length_difference < 0:
        for _ in range(abs(length_difference)):
            list1.append("N/A")
    # Else if list2 is the shorter one.
    elif length_difference > 0:
        for _ in range(length_difference):
            list2.append("N/A")
    # If they're already equal, they both leave the courtroom with dignity.

# %%
# Datafame Format 1: (combined statements)
statements = []
brands = []
apps = []
texts = []

position = 0
for outcome in df['outcome_raw']:

    brand_name = df['brand_name'][position]
    app_no = df['application_number'][position]
    original_text = df['clinical_studies'][position]

    metrics = extract_metrics(outcome)
    values = extract_values(outcome)
    descriptors = extract_descriptors(outcome)

    equalize_list_lengths(metrics, values)
    equalize_list_lengths(metrics, descriptors)

    for i in range(len(metrics)):
        statement = f'{metrics[i]}: {values[i]} ({descriptors[i]})'

        statements.append(statement)
        brands.append(brand_name)
        apps.append(app_no)
        texts.append(original_text)

    position += 1

data_format1 = pd.DataFrame().assign(brand_name=brands,application=apps,original_text=texts,statement=statements)
data_format1
# Out:
#                                 brand_name application  \
# 0    AMOXICILLIN AND CLAVULANATE POTASSIUM  ANDA065117
# 1    AMOXICILLIN AND CLAVULANATE POTASSIUM  ANDA065117
# 2    AMOXICILLIN AND CLAVULANATE POTASSIUM  ANDA065117
# 3                                ARTHROTEC   NDA020607
# 4                                ARTHROTEC   NDA020607
# ..                                     ...         ...
# 458                             Alprazolam  ANDA074342
# 459                             Alprazolam  ANDA074342
# 460                            Sumatriptan  ANDA202758
# 461                                    NaN         NaN
# 462                                    NaN         NaN
#
#                                          original_text  \
# 0    CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 1    CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 2    CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 3    14 CLINICAL STUDIES Osteoarthritis Diclofenac ...
# 4    14 CLINICAL STUDIES Osteoarthritis Diclofenac ...
# ..                                                 ...
# 458  14 CLINICAL STUDIES 14.1 Generalized Anxiety D...
# 459  14 CLINICAL STUDIES 14.1 Generalized Anxiety D...
# 460  14 CLINICAL STUDIES 14.1 Migraine In controlle...
# 461  14 CLINICAL STUDIES Olmesartan medoxomil and h...
# 462  14 CLINICAL STUDIES Olmesartan medoxomil and h...
#
#                                              statement
# 0    H. pylori eradication: Triple therapy was more...
# 1    H. pylori eradication: Dual therapy was more e...
# 2    Duodenal ulcer recurrence: Eradication of H. p...
# 3    Gastric ulcer prevention: 6% (Reduced incidenc...
# 4    Duodenal ulcer prevention: 3% (Reduced inciden...
# ..                                                 ...
# 458  Alprazolam vs Placebo: Superior to placebo on ...
# 459                   Alprazolam vs Placebo: N/A (N/A)
# 460  clinical trial: 14 (Studies enrolling more tha...
# 461  blood pressure reduction: 17/8 mm Hg (mean pla...
# 462  blood pressure reduction: 14/5 mm Hg (mean pla...
#
# [463 rows x 4 columns]

# %%
# Datafame Format 2: (separated metrics, values, descriptors)
metric_list = []
value_list = []
descriptor_list = []

texts = []
brands = []
apps = []

position = 0
for outcome in df['outcome_raw']:

    brand_name = df['brand_name'][position]
    app_no = df['application_number'][position]
    original_text = df['clinical_studies'][position]

    metrics = extract_metrics(outcome)
    values = extract_values(outcome)
    descriptors = extract_descriptors(outcome)

    equalize_list_lengths(metrics, values)
    equalize_list_lengths(metrics, descriptors)

    for i in range(len(metrics)):
        metric_list.append(metrics[i])
        value_list.append(values[i])
        descriptor_list.append(descriptors[i])

        texts.append(original_text)
        brands.append(brand_name)
        apps.append(app_no)

    position += 1

data_format2 = pd.DataFrame().assign(brand_name=brands,application=apps,original_text=texts,metrics=metric_list,values=value_list,descriptors=descriptor_list)
data_format2
# Out:
#                                 brand_name application  \
# 0    AMOXICILLIN AND CLAVULANATE POTASSIUM  ANDA065117
# 1    AMOXICILLIN AND CLAVULANATE POTASSIUM  ANDA065117
# 2    AMOXICILLIN AND CLAVULANATE POTASSIUM  ANDA065117
# 3                                ARTHROTEC   NDA020607
# 4                                ARTHROTEC   NDA020607
# ..                                     ...         ...
# 458                             Alprazolam  ANDA074342
# 459                             Alprazolam  ANDA074342
# 460                            Sumatriptan  ANDA202758
# 461                                    NaN         NaN
# 462                                    NaN         NaN
#
#                                          original_text  \
# 0    CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 1    CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 2    CLINICAL STUDIES SECTION 14.1 H. pylori Eradic...
# 3    14 CLINICAL STUDIES Osteoarthritis Diclofenac ...
# 4    14 CLINICAL STUDIES Osteoarthritis Diclofenac ...
# ..                                                 ...
# 458  14 CLINICAL STUDIES 14.1 Generalized Anxiety D...
# 459  14 CLINICAL STUDIES 14.1 Generalized Anxiety D...
# 460  14 CLINICAL STUDIES 14.1 Migraine In controlle...
# 461  14 CLINICAL STUDIES Olmesartan medoxomil and h...
# 462  14 CLINICAL STUDIES Olmesartan medoxomil and h...
#
#                        metrics  \
# 0        H. pylori eradication
# 1        H. pylori eradication
# 2    Duodenal ulcer recurrence
# 3     Gastric ulcer prevention
# 4    Duodenal ulcer prevention
# ..                         ...
# 458      Alprazolam vs Placebo
# 459      Alprazolam vs Placebo
# 460             clinical trial
# 461   blood pressure reduction
# 462   blood pressure reduction
#
#                                                 values  \
# 0    Triple therapy was more effective than all pos...
# 1    Dual therapy was more effective than both mono...
# 2    Eradication of H. pylori has been shown to red...
# 3                                                   6%
# 4                                                   3%
# ..                                                 ...
# 458  Superior to placebo on a variable defined as '...
# 459                                                N/A
# 460                                                 14
# 461                                         17/8 mm Hg
# 462                                         14/5 mm Hg
#
#                                            descriptors
# 0    Primary treatment outcome for patients with H....
# 1    Primary treatment outcome for patients with H....
# 2                                                  N/A
# 3    Reduced incidence of gastric ulcers in osteoar...
# 4    Reduced incidence of duodenal ulcers with all ...
# ..                                                 ...
# 458          3 short-term, placebo-controlled studies.
# 459                                                N/A
# 460  Studies enrolling more than 1,000 patients dur...
# 461  mean placebo-adjusted trough blood pressure re...
# 462  mean placebo-adjusted trough blood pressure re...
#
# [463 rows x 6 columns]

# %% [markdown]
# ## Inspect Data
# Spot check the data for correctness and interpretability

# %%
# Straightforward and Correct:              0,1,6,7
# Straightforward and Not Correct:
# Difficult to Interpret, but Correct:      3,4
# Difficult to Interpret, incorrect:        5
# Not Interprettable:
# Not an Outcome:                           2

spot_check = 8
print(f'{data_format2["application"][spot_check]}\n\n{data_format2["original_text"][spot_check]} \n\n\n{data_format2["metrics"][spot_check]} : {data_format2["values"][spot_check]} \n ({data_format2["descriptors"][spot_check]})')
# Out:
# BLA761104
#
# 14 CLINICAL STUDIES The efficacy of LUMOXITI was based upon Study 1053 titled “A Pivotal Multicenter Trial of Moxetumomab Pasudotox in Relapsed/Refractory Hairy Cell Leukemia” (NCT01829711). Study 1053 was conducted in patients with histologically confirmed HCL or HCL variant with a need for therapy based on presence of cytopenias or splenomegaly and who had received prior treatment with at least 2 systemic therapies, including 1 purine nucleoside analog (PNA). Eligible patients had serum creatinine ≤ 1.5 mg/dL or creatinine clearance ≥ 60 mL/min as estimated by the Cockcroft Gault equation. A total of 80 patients were enrolled; 77 with classic HCL and 3 with HCL variant. The median age was 60 years (range: 34 to 84) years, 79% were male, and 94% were Caucasian. At baseline, 98% of patients had an ECOG performance status of 0 or 1. The median number of prior treatments was 3 (range: 2 to 11); all patients received prior PNA therapy, including 29% in combination with rituximab. The most common other prior treatment regimens were rituximab monotherapy (51%), interferon-alpha (25%), and a BRAF inhibitor (18%). At baseline, 33% (26/80) of patients had low hemoglobin (< 10 g/dL), 68% (54/80) of patients had neutropenia (< 1000/mm 3 ), and 84% (67/80) patients had baseline platelet counts < 100,000/mm 3 . About 35% of patients had enlarged spleens (≥ 14 cm, assessed by BICR) at baseline. Patients received LUMOXITI 0.04 mg/kg as an intravenous infusion over 30 minutes on Days 1, 3, and 5 of each 28‑day cycle for a maximum of 6 cycles or until documentation of complete response (CR), disease progression, or unacceptable toxicity. The median duration of follow-up was 16.7 months (range: 2 to 49). An independent review committee (IRC) performed efficacy evaluations using blood, bone marrow, and imaging criteria adapted from previous HCL studies and consensus guidelines. Efficacy of LUMOXITI in HCL was evaluated by the IRC-assessed rate of durable CR, as confirmed by maintenance of hematologic remission (hemoglobin ≥ 11 g/dL, neutrophils ≥ 1500/mm 3 , and platelets ≥ 100,000/mm 3 without transfusions or growth factor for at least 4 weeks) more than 180 days after IRC-assessed CR. The IRC-assessed durable CR rate was 30% (24/80 patients; 95% CI: 20, 41). Additional efficacy outcome measures included overall response rate (ORR), CR, and duration of response (see Table 6). Table 6: Additional Efficacy Results in Patients with HCL in Study 1053 Independent Review Committee (IRC) Assessed N=80 Overall Response Rate Overall Response Rate ORR defined as best overall response of CR or PR. (%) [95% CI] 75 [64, 84] Complete Response CR defined as clearing of the bone marrow of hairy cells by routine Hematoxylin & Eosin stain, radiologic resolution of pre-existing lymphadenopathy and/or organomegaly, and hematologic remission. (%) [95% CI] 41 [30, 53] Partial Response PR defined as ≥ 50% decrease or normalization (< 500/mm 3 ) in peripheral blood lymphocyte count, reduction of pre-existing lymphadenopathy and/or organomegaly, and hematologic remission. (%) [95% CI] 34 [24, 45] Duration of Response Median in months [range] NR [0+ to 43+] Duration of CR Median in months [range] NR [0+ to 40+] CI=Confidence Interval; NR=Not Reached; + indicates censored observations The median time to ORR and CR was 5.7 months (range: 1.8 to 12.9) and 5.9 months (range 1.8 to 13.2), respectively. Sixty-four patients (80%) had normalization of hematologic parameters and achieved hematologic remission, with a median time to hematologic remission of 1.1 months (range: 0.2 to 13) and with a median duration of hematologic remission not reached (range: 0.3 to 48.2+).
#
#
# durable complete response rate : 30%
#  (Independent Review Committee (IRC)-assessed rate of durable CR, as confirmed by maintenance of hematologic remission (hemoglobin ≥ 11 g/dL, neutrophils ≥ 1500/mm 3 , and platelets ≥ 100,000/mm 3 without transfusions or growth factor for at least 4 weeks) more than 180 days after IRC-assessed CR.)
