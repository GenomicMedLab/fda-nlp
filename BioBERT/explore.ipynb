# %%
from datasets import load_dataset

dataset = load_dataset("conll2003")
# Out:
# Downloading builder script:   0%|          | 0.00/9.57k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/12.3k [00:00<?, ?B/s]
# Downloading and preparing dataset conll2003/conll2003 to /Users/mjc014/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98...
# Downloading data:   0%|          | 0.00/983k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]
# Dataset conll2003 downloaded and prepared to /Users/mjc014/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset['train'][0]
# Out:
# {'id': '0',
#  'tokens': ['EU',
#   'rejects',
#   'German',
#   'call',
#   'to',
#   'boycott',
#   'British',
#   'lamb',
#   '.'],
#  'pos_tags': [22, 42, 16, 21, 35, 37, 16, 21, 7],
#  'chunk_tags': [11, 21, 11, 12, 21, 22, 11, 12, 0],
#  'ner_tags': [3, 0, 7, 0, 0, 0, 7, 0, 0]}

# %%
dataset['train'].features
# Out:
# {'id': Value(dtype='string', id=None),
#  'tokens': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#  'pos_tags': Sequence(feature=ClassLabel(names=['"', "''", '#', '$', '(', ')', ',', '.', ':', '``', 'CC', 'CD', 'DT', 'EX', 'FW', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NN', 'NNP', 'NNPS', 'NNS', 'NN|SYM', 'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'SYM', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB'], id=None), length=-1, id=None),
#  'chunk_tags': Sequence(feature=ClassLabel(names=['O', 'B-ADJP', 'I-ADJP', 'B-ADVP', 'I-ADVP', 'B-CONJP', 'I-CONJP', 'B-INTJ', 'I-INTJ', 'B-LST', 'I-LST', 'B-NP', 'I-NP', 'B-PP', 'I-PP', 'B-PRT', 'I-PRT', 'B-SBAR', 'I-SBAR', 'B-UCP', 'I-UCP', 'B-VP', 'I-VP'], id=None), length=-1, id=None),
#  'ner_tags': Sequence(feature=ClassLabel(names=['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC'], id=None), length=-1, id=None)}

# %%
dataset['train'][0]['tokens']
# Out:
# ['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.']

# %% [markdown]
# ### Try some models for NER?

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext")
model = AutoModelForMaskedLM.from_pretrained("microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext")
# Out:
# 2023-08-24 08:44:31.874763: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
my_dataset = load_dataset("../old-data/kindred-data-sets/indication_pages")
# Out:
# Resolving data files:   0%|          | 0/647 [00:00<?, ?it/s]
# Downloading and preparing dataset text/indication_pages to /Users/mjc014/.cache/huggingface/datasets/text/indication_pages-3968f876ec7b966a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset text downloaded and prepared to /Users/mjc014/.cache/huggingface/datasets/text/indication_pages-3968f876ec7b966a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
my_dataset['train'][0]
# Out:
# {'text': '                                                                                                                                                                                                                                                             The plastic container is made from a multilayered film specifically developed for parenteral drugs. It contains no plasticizers and  exhibits virtually no leachables. The solution contact layer is a rubberized copolymer of ethylene and propylene. The container is  nontoxic and biologically inert. The container-solution unit is a closed system and is not dependent upon entry of external air  during administration. The container is overwrapped to provide protection from the physical environment and to provide an  additional moisture barrier when necessary.  The closure system has two ports; the one for the administration set has a tamper evident plastic protector. Refer to the  Directions for Use of the container.  CLINICAL PHARMACOLOGY  Lidocaine hydrochloride exerts an antiarrhythmic effect by increasing the electric stimulation threshold of the ventricle during  diastole. In usual therapeutic doses, lidocaine hydrochloride produces no change in myocardial contractility, in systemic arterial  pressure, or in absolute refractory period.  About 90% of an administered dose of the drug is metabolized in the liver. The remaining 10% is excreted unchanged via the  kidneys.  Lidocaine toxicity is related to systemic blood levels. The decreased clearance and longer half-life of lidocaine should be taken  into consideration with prolonged (24 hour) infusions. Constant rate of infusion may result in toxic accumulation of lidocaine.  Infusion should be reduced to approximately one-half to compensate for decreased rate of clearance and concomitant or prior  administration of propranolol may further increase blood concentrations by as much as 30% in patients without cardiac or hepatic  failure. In clinical studies, patients over 65 years showed decreased lidocaine clearance. This was partly due to the tendency of  elderly patients to have lower body weight and the increased risk of cardiac failure in these patients.  This solution provides approximately 170 calories per liter.  INDICATIONS AND USAGE  Lidocaine hydrochloride administered intravenously is specifically indicated in the acute management of (1) ventricular  arrhythmias occurring during cardiac manipulations, such as cardiac surgery and (2) life-threatening arrhythmias which are  ventricular in origin, such as occur during acute myocardial infarction.  CONTRAINDICATIONS  Lidocaine hydrochloride is contraindicated in patients with a known history of hypersensitivity to local anesthetics of the amide  type.  Lidocaine should not be used in patients with Stokes-Adams syndrome, Wolff-Parkinson-White syndrome, or with severe  degrees of sinoatrial, atrioventricular, or intraventricular block.  Solutions containing dextrose may be contraindicated in patients with known allergy to corn or corn products.  WARNINGS   Reference ID: 4610813  '}

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM, pipeline

tokenizer = AutoTokenizer.from_pretrained("chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")
model = AutoModelForMaskedLM.from_pretrained("chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")

pipe = pipeline("token-classification", model="chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/228k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/717k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/54.0M [00:00<?, ?B/s]
# Some weights of the model checkpoint at chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3 were not used when initializing ElectraForMaskedLM: ['classifier.bias', 'classifier.weight']
# - This IS expected if you are initializing ElectraForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForMaskedLM were not initialized from the model checkpoint at chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3 and are newly initialized: ['generator_lm_head.bias', 'generator_predictions.dense.bias', 'generator_predictions.dense.weight', 'generator_predictions.LayerNorm.weight', 'generator_predictions.LayerNorm.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def make_tokens(text):
    return {'tokens' : tokenizer.tokenize(text['text'])}

my_dataset = my_dataset.filter(lambda x: x['text'] is not None)

my_dataset = my_dataset.map(make_tokens)
# Out:
# Loading cached processed dataset at /Users/mjc014/.cache/huggingface/datasets/text/indication_pages-3968f876ec7b966a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-857313cc5f7b8273.arrow
# Map:   0%|          | 0/647 [00:00<?, ? examples/s]

# %%
my_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'tokens'],
#         num_rows: 647
#     })
# })

# %%
pipe = pipeline("token-classification", model="chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")
pipe(my_dataset['train'][0]['tokens'])
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [[],
#  [{'entity': 'B-DRUG',
#    'score': 0.31315148,
#    'index': 1,
#    'word': 'plastic',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.3816811,
#    'index': 1,
#    'word': 'a',
#    'start': 0,
#    'end': 1}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.31315148,
#    'index': 1,
#    'word': 'plastic',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.54664373,
#    'index': 1,
#    'word': 'leach',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.35858142,
#    'index': 1,
#    'word': 'solution',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5007999,
#    'index': 1,
#    'word': 'contact',
#    'start': 0,
#    'end': 7}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.419171,
#    'index': 1,
#    'word': 'layer',
#    'start': 0,
#    'end': 5}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.3816811,
#    'index': 1,
#    'word': 'a',
#    'start': 0,
#    'end': 1}],
#  [{'entity': 'B-DRUG',
#    'score': 0.57503945,
#    'index': 1,
#    'word': 'rubber',
#    'start': 0,
#    'end': 6}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.8111955,
#    'index': 1,
#    'word': 'ethylene',
#    'start': 0,
#    'end': 8}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.6707994,
#    'index': 1,
#    'word': 'prop',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6775335,
#    'index': 1,
#    'word': 'non',
#    'start': 0,
#    'end': 3}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4330602,
#    'index': 3,
#    'word': 'toxic',
#    'start': 2,
#    'end': 7}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.52080303,
#    'index': 1,
#    'word': 'inert',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.35858142,
#    'index': 1,
#    'word': 'solution',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.3816811,
#    'index': 1,
#    'word': 'a',
#    'start': 0,
#    'end': 1}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.38381675,
#    'index': 1,
#    'word': 'external',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.35817873,
#    'index': 1,
#    'word': 'air',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'I-EFFECT',
#    'score': 0.47059494,
#    'index': 1,
#    'word': 'overw',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4608628,
#    'index': 1,
#    'word': 'protection',
#    'start': 0,
#    'end': 10}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.41473666,
#    'index': 1,
#    'word': 'physical',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.46395275,
#    'index': 1,
#    'word': 'moisture',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.60790265,
#    'index': 1,
#    'word': 'barrier',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.3907091,
#    'index': 1,
#    'word': 'ports',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.3816811,
#    'index': 1,
#    'word': 'a',
#    'start': 0,
#    'end': 1}],
#  [{'entity': 'B-DRUG',
#    'score': 0.76114285,
#    'index': 1,
#    'word': 'tam',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.31315148,
#    'index': 1,
#    'word': 'plastic',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.47109428,
#    'index': 1,
#    'word': 'pharmacology',
#    'start': 0,
#    'end': 12}],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-DRUG',
#    'score': 0.8387004,
#    'index': 1,
#    'word': 'hydrochloride',
#    'start': 0,
#    'end': 13}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4752021,
#    'index': 1,
#    'word': 'anti',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'I-EFFECT',
#    'score': 0.44866785,
#    'index': 3,
#    'word': 'arrhyth',
#    'start': 2,
#    'end': 9}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.48255447,
#    'index': 1,
#    'word': 'effect',
#    'start': 0,
#    'end': 6}],
#  [{'entity': 'B-DRUG',
#    'score': 0.28794652,
#    'index': 1,
#    'word': 'by',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.604565,
#    'index': 1,
#    'word': 'electric',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-DRUG',
#    'score': 0.3599121,
#    'index': 1,
#    'word': 'stimulation',
#    'start': 0,
#    'end': 11}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6701027,
#    'index': 1,
#    'word': 'ventricle',
#    'start': 0,
#    'end': 9}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6274027,
#    'index': 1,
#    'word': 'dias',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-DRUG',
#    'score': 0.8387004,
#    'index': 1,
#    'word': 'hydrochloride',
#    'start': 0,
#    'end': 13}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7771752,
#    'index': 1,
#    'word': 'change',
#    'start': 0,
#    'end': 6}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.75927997,
#    'index': 1,
#    'word': 'myocardial',
#    'start': 0,
#    'end': 10}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6789929,
#    'index': 1,
#    'word': 'contractility',
#    'start': 0,
#    'end': 13}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4661586,
#    'index': 1,
#    'word': 'systemic',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'I-EFFECT',
#    'score': 0.4331255,
#    'index': 1,
#    'word': 'arterial',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.68659174,
#    'index': 1,
#    'word': 'pressure',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6693666,
#    'index': 1,
#    'word': 'refractory',
#    'start': 0,
#    'end': 10}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.37942415,
#    'index': 1,
#    'word': '%',
#    'start': 0,
#    'end': 1}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.37275803,
#    'index': 1,
#    'word': 'dose',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.29866472,
#    'index': 1,
#    'word': 'drug',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5030228,
#    'index': 1,
#    'word': 'metabol',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.69383484,
#    'index': 1,
#    'word': 'liver',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.37942415,
#    'index': 1,
#    'word': '%',
#    'start': 0,
#    'end': 1}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.41966966,
#    'index': 1,
#    'word': 'exc',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.34730053,
#    'index': 1,
#    'word': 'via',
#    'start': 0,
#    'end': 3}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6617178,
#    'index': 1,
#    'word': 'kidneys',
#    'start': 0,
#    'end': 7}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6900624,
#    'index': 1,
#    'word': 'toxicity',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4661586,
#    'index': 1,
#    'word': 'systemic',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.46870235,
#    'index': 1,
#    'word': 'blood',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5658155,
#    'index': 1,
#    'word': 'decreased',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6543615,
#    'index': 1,
#    'word': 'clearance',
#    'start': 0,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.49204174,
#    'index': 1,
#    'word': 'life',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.44511145,
#    'index': 1,
#    'word': 'rate',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.39708105,
#    'index': 1,
#    'word': 'result',
#    'start': 0,
#    'end': 6}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6567695,
#    'index': 1,
#    'word': 'toxic',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7355516,
#    'index': 1,
#    'word': 'accumulation',
#    'start': 0,
#    'end': 12}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.47418007,
#    'index': 1,
#    'word': 'reduced',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5658155,
#    'index': 1,
#    'word': 'decreased',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.44511145,
#    'index': 1,
#    'word': 'rate',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6543615,
#    'index': 1,
#    'word': 'clearance',
#    'start': 0,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.6707994,
#    'index': 1,
#    'word': 'prop',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6770763,
#    'index': 1,
#    'word': 'increase',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.46870235,
#    'index': 1,
#    'word': 'blood',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.36172467,
#    'index': 1,
#    'word': 'concentrations',
#    'start': 0,
#    'end': 14}],
#  [{'entity': 'B-DRUG',
#    'score': 0.28794652,
#    'index': 1,
#    'word': 'by',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.37942415,
#    'index': 1,
#    'word': '%',
#    'start': 0,
#    'end': 1}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7242551,
#    'index': 1,
#    'word': 'cardiac',
#    'start': 0,
#    'end': 7}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7565127,
#    'index': 1,
#    'word': 'hepatic',
#    'start': 0,
#    'end': 7}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.77419585,
#    'index': 1,
#    'word': 'failure',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5658155,
#    'index': 1,
#    'word': 'decreased',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6543615,
#    'index': 1,
#    'word': 'clearance',
#    'start': 0,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.60190606,
#    'index': 1,
#    'word': 'tendency',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5750138,
#    'index': 1,
#    'word': 'body',
#    'start': 0,
#    'end': 4}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5824403,
#    'index': 1,
#    'word': 'weight',
#    'start': 0,
#    'end': 6}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.55313903,
#    'index': 1,
#    'word': 'increased',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5392974,
#    'index': 1,
#    'word': 'risk',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7242551,
#    'index': 1,
#    'word': 'cardiac',
#    'start': 0,
#    'end': 7}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.77419585,
#    'index': 1,
#    'word': 'failure',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.35858142,
#    'index': 1,
#    'word': 'solution',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [{'entity': 'I-EFFECT',
#    'score': 0.38084874,
#    'index': 1,
#    'word': 'calor',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.41231012,
#    'index': 1,
#    'word': 'usage',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-DRUG',
#    'score': 0.8387004,
#    'index': 1,
#    'word': 'hydrochloride',
#    'start': 0,
#    'end': 13}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.60998696,
#    'index': 1,
#    'word': 'acute',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5801771,
#    'index': 1,
#    'word': 'ventricular',
#    'start': 0,
#    'end': 11}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7416275,
#    'index': 1,
#    'word': 'arrhythmias',
#    'start': 0,
#    'end': 11}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7242551,
#    'index': 1,
#    'word': 'cardiac',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7242551,
#    'index': 1,
#    'word': 'cardiac',
#    'start': 0,
#    'end': 7}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.49204174,
#    'index': 1,
#    'word': 'life',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.53879744,
#    'index': 1,
#    'word': 'threatening',
#    'start': 0,
#    'end': 11}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7416275,
#    'index': 1,
#    'word': 'arrhythmias',
#    'start': 0,
#    'end': 11}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5801771,
#    'index': 1,
#    'word': 'ventricular',
#    'start': 0,
#    'end': 11}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.60998696,
#    'index': 1,
#    'word': 'acute',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.75927997,
#    'index': 1,
#    'word': 'myocardial',
#    'start': 0,
#    'end': 10}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.8126791,
#    'index': 1,
#    'word': 'infarction',
#    'start': 0,
#    'end': 10}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4876162,
#    'index': 1,
#    'word': 'contrain',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [{'entity': 'B-DRUG',
#    'score': 0.8387004,
#    'index': 1,
#    'word': 'hydrochloride',
#    'start': 0,
#    'end': 13}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4876162,
#    'index': 1,
#    'word': 'contrain',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.3816811,
#    'index': 1,
#    'word': 'a',
#    'start': 0,
#    'end': 1}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.64419055,
#    'index': 1,
#    'word': 'hypersen',
#    'start': 0,
#    'end': 8}],
#  [{'entity': 'I-EFFECT',
#    'score': 0.48162603,
#    'index': 4,
#    'word': '##ivity',
#    'start': 5,
#    'end': 10}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.47643882,
#    'index': 1,
#    'word': 'anesthetic',
#    'start': 0,
#    'end': 10}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.3527247,
#    'index': 1,
#    'word': 'amide',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.60587233,
#    'index': 1,
#    'word': 'type',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.74057174,
#    'index': 1,
#    'word': 'lidocaine',
#    'start': 0,
#    'end': 9}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5730726,
#    'index': 1,
#    'word': 'stokes',
#    'start': 0,
#    'end': 6}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.58240336,
#    'index': 1,
#    'word': 'adams',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.822682,
#    'index': 1,
#    'word': 'syndrome',
#    'start': 0,
#    'end': 8}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.69824237,
#    'index': 1,
#    'word': 'wolf',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.76468354,
#    'index': 1,
#    'word': 'parkinson',
#    'start': 0,
#    'end': 9}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.67066044,
#    'index': 1,
#    'word': 'white',
#    'start': 0,
#    'end': 5}],
#  [{'entity': 'B-EFFECT',
#    'score': 0.822682,
#    'index': 1,
#    'word': 'syndrome',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6197223,
#    'index': 1,
#    'word': 'severe',
#    'start': 0,
#    'end': 6}],
#  [{'entity': 'I-EFFECT',
#    'score': 0.33232948,
#    'index': 1,
#    'word': 'degrees',
#    'start': 0,
#    'end': 7}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.43270406,
#    'index': 1,
#    'word': 'sin',
#    'start': 0,
#    'end': 3}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.84729016,
#    'index': 1,
#    'word': 'atr',
#    'start': 0,
#    'end': 3}],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.46105215,
#    'index': 3,
#    'word': 'ventricular',
#    'start': 2,
#    'end': 13}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.5448047,
#    'index': 1,
#    'word': 'intraven',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6960836,
#    'index': 1,
#    'word': 'block',
#    'start': 0,
#    'end': 5}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.78482157,
#    'index': 1,
#    'word': 'dext',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.4876162,
#    'index': 1,
#    'word': 'contrain',
#    'start': 0,
#    'end': 8}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.7761352,
#    'index': 1,
#    'word': 'allergy',
#    'start': 0,
#    'end': 7}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.7152041,
#    'index': 1,
#    'word': 'corn',
#    'start': 0,
#    'end': 4}],
#  [],
#  [{'entity': 'B-DRUG',
#    'score': 0.7152041,
#    'index': 1,
#    'word': 'corn',
#    'start': 0,
#    'end': 4}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'entity': 'B-EFFECT',
#    'score': 0.6519659,
#    'index': 1,
#    'word': 'id',
#    'start': 0,
#    'end': 2}],
#  [],
#  [],
#  [],
#  []]
