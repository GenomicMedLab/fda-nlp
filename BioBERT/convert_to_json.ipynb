# %% [markdown]
# ## Convert free-text to JSON representations

# %% [markdown]
# In previous exercise with Kindred, PDF labels from Drugs@FDA were used as follows:
#
# 1. PDFs were downloaded
# 2. PDFs were converted to free-text files.
# 3. Free-text files were then separated into different sections for Indications, Contraindications, and Adverse Effects.
#
# This separation was chosen as the types of named entities and relationships would be largely identical, but with different inferred meanings dependent on the section they were present within (this seemed a hard problem to address).

# %% [markdown]
# For this exercise, I am thinking about how to re-format this dataset for use in HuggingFace models. The aim of this research is to take an existing pretrained model, such as BioNLP, and train it further for **entity recognition** of drugs, genes, variants, and phenotypes. Following this, train the model further to perform **text summarization** to summarize a label to link drugs, genes, variants, phenotypes within one individual 'claim'.

# %% [markdown]
# In thinking about this, I think the data should eventually be formatted like this:

# %%
# JSON format
{
    "meta": { "label": <identifier>,
                "drug": <drug label>,
                "type": <type of page, i.e. indication, adverse effects, contraindications>,
                "url": <url of label download>,
            },
    "text": <free text dump>,
    "tokens": [...],
    "pos_tags": [...], # IDs
    "chunk_tags": [...], # IDs
    "ner_tags": [...], # IDs
    "id": <identifier for data point>

}

# %% [markdown]
# This I think is the data format that needs to happen to make a training set for at least named entity recognition?

# %% [markdown]
# ### Loading the Dataset

# %%
from datasets import load_dataset
dataset = load_dataset("../old-data/kindred-data-sets/indication_pages")
dataset
# Out:
# Resolving data files:   0%|          | 0/647 [00:00<?, ?it/s]
# Found cached dataset text (/Users/mjc014/.cache/huggingface/datasets/text/indication_pages-3968f876ec7b966a/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 647
#     })
# })

# %%
dataset['train'].features
# Out:
# {'text': Value(dtype='string', id=None)}

# %%
dataset['train'][0]
# Out:
# {'text': '                                                                                                                                                                                                                                                             The plastic container is made from a multilayered film specifically developed for parenteral drugs. It contains no plasticizers and  exhibits virtually no leachables. The solution contact layer is a rubberized copolymer of ethylene and propylene. The container is  nontoxic and biologically inert. The container-solution unit is a closed system and is not dependent upon entry of external air  during administration. The container is overwrapped to provide protection from the physical environment and to provide an  additional moisture barrier when necessary.  The closure system has two ports; the one for the administration set has a tamper evident plastic protector. Refer to the  Directions for Use of the container.  CLINICAL PHARMACOLOGY  Lidocaine hydrochloride exerts an antiarrhythmic effect by increasing the electric stimulation threshold of the ventricle during  diastole. In usual therapeutic doses, lidocaine hydrochloride produces no change in myocardial contractility, in systemic arterial  pressure, or in absolute refractory period.  About 90% of an administered dose of the drug is metabolized in the liver. The remaining 10% is excreted unchanged via the  kidneys.  Lidocaine toxicity is related to systemic blood levels. The decreased clearance and longer half-life of lidocaine should be taken  into consideration with prolonged (24 hour) infusions. Constant rate of infusion may result in toxic accumulation of lidocaine.  Infusion should be reduced to approximately one-half to compensate for decreased rate of clearance and concomitant or prior  administration of propranolol may further increase blood concentrations by as much as 30% in patients without cardiac or hepatic  failure. In clinical studies, patients over 65 years showed decreased lidocaine clearance. This was partly due to the tendency of  elderly patients to have lower body weight and the increased risk of cardiac failure in these patients.  This solution provides approximately 170 calories per liter.  INDICATIONS AND USAGE  Lidocaine hydrochloride administered intravenously is specifically indicated in the acute management of (1) ventricular  arrhythmias occurring during cardiac manipulations, such as cardiac surgery and (2) life-threatening arrhythmias which are  ventricular in origin, such as occur during acute myocardial infarction.  CONTRAINDICATIONS  Lidocaine hydrochloride is contraindicated in patients with a known history of hypersensitivity to local anesthetics of the amide  type.  Lidocaine should not be used in patients with Stokes-Adams syndrome, Wolff-Parkinson-White syndrome, or with severe  degrees of sinoatrial, atrioventricular, or intraventricular block.  Solutions containing dextrose may be contraindicated in patients with known allergy to corn or corn products.  WARNINGS   Reference ID: 4610813  '}

# %% [markdown]
# ### Tokenize

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForMaskedLM, pipeline

tokenizer = AutoTokenizer.from_pretrained("microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext")
model = AutoModelForMaskedLM.from_pretrained("microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext")
pipe = pipeline("token-classification", model="chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")
# Out:
# Some weights of the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def make_tokens(text):
    return {'tokens' : tokenizer.tokenize(text['text'])}

dataset = dataset.filter(lambda x: x['text'] is not None)

dataset = dataset.map(make_tokens)
# Out:
# Filter:   0%|          | 0/647 [00:00<?, ? examples/s]
# Map:   0%|          | 0/647 [00:00<?, ? examples/s]

# %%
dataset[0]
# Out:
# {'text': '                                                                                                                                                                                                                                                             The plastic container is made from a multilayered film specifically developed for parenteral drugs. It contains no plasticizers and  exhibits virtually no leachables. The solution contact layer is a rubberized copolymer of ethylene and propylene. The container is  nontoxic and biologically inert. The container-solution unit is a closed system and is not dependent upon entry of external air  during administration. The container is overwrapped to provide protection from the physical environment and to provide an  additional moisture barrier when necessary.  The closure system has two ports; the one for the administration set has a tamper evident plastic protector. Refer to the  Directions for Use of the container.  CLINICAL PHARMACOLOGY  Lidocaine hydrochloride exerts an antiarrhythmic effect by increasing the electric stimulation threshold of the ventricle during  diastole. In usual therapeutic doses, lidocaine hydrochloride produces no change in myocardial contractility, in systemic arterial  pressure, or in absolute refractory period.  About 90% of an administered dose of the drug is metabolized in the liver. The remaining 10% is excreted unchanged via the  kidneys.  Lidocaine toxicity is related to systemic blood levels. The decreased clearance and longer half-life of lidocaine should be taken  into consideration with prolonged (24 hour) infusions. Constant rate of infusion may result in toxic accumulation of lidocaine.  Infusion should be reduced to approximately one-half to compensate for decreased rate of clearance and concomitant or prior  administration of propranolol may further increase blood concentrations by as much as 30% in patients without cardiac or hepatic  failure. In clinical studies, patients over 65 years showed decreased lidocaine clearance. This was partly due to the tendency of  elderly patients to have lower body weight and the increased risk of cardiac failure in these patients.  This solution provides approximately 170 calories per liter.  INDICATIONS AND USAGE  Lidocaine hydrochloride administered intravenously is specifically indicated in the acute management of (1) ventricular  arrhythmias occurring during cardiac manipulations, such as cardiac surgery and (2) life-threatening arrhythmias which are  ventricular in origin, such as occur during acute myocardial infarction.  CONTRAINDICATIONS  Lidocaine hydrochloride is contraindicated in patients with a known history of hypersensitivity to local anesthetics of the amide  type.  Lidocaine should not be used in patients with Stokes-Adams syndrome, Wolff-Parkinson-White syndrome, or with severe  degrees of sinoatrial, atrioventricular, or intraventricular block.  Solutions containing dextrose may be contraindicated in patients with known allergy to corn or corn products.  WARNINGS   Reference ID: 4610813  ',
#  'tokens': ['the',
#   'plastic',
#   'container',
#   'is',
#   'made',
#   'from',
#   'a',
#   'multilayer',
#   '##ed',
#   'film',
#   'specifically',
#   'developed',
#   'for',
#   'parenteral',
#   'drugs',
#   '.',
#   'it',
#   'contains',
#   'no',
#   'plastic',
#   '##izers',
#   'and',
#   'exhibits',
#   'virtually',
#   'no',
#   'le',
#   '##ach',
#   '##ables',
#   '.',
#   'the',
#   'solution',
#   'contact',
#   'layer',
#   'is',
#   'a',
#   'rubber',
#   '##ized',
#   'copolymer',
#   'of',
#   'ethylene',
#   'and',
#   'propyl',
#   '##ene',
#   '.',
#   'the',
#   'container',
#   'is',
#   'nont',
#   '##oxic',
#   'and',
#   'biologically',
#   'inert',
#   '.',
#   'the',
#   'container',
#   '-',
#   'solution',
#   'unit',
#   'is',
#   'a',
#   'closed',
#   'system',
#   'and',
#   'is',
#   'not',
#   'dependent',
#   'upon',
#   'entry',
#   'of',
#   'external',
#   'air',
#   'during',
#   'administration',
#   '.',
#   'the',
#   'container',
#   'is',
#   'over',
#   '##wr',
#   '##apped',
#   'to',
#   'provide',
#   'protection',
#   'from',
#   'the',
#   'physical',
#   'environment',
#   'and',
#   'to',
#   'provide',
#   'an',
#   'additional',
#   'moisture',
#   'barrier',
#   'when',
#   'necessary',
#   '.',
#   'the',
#   'closure',
#   'system',
#   'has',
#   'two',
#   'port',
#   '##s',
#   ';',
#   'the',
#   'one',
#   'for',
#   'the',
#   'administration',
#   'set',
#   'has',
#   'a',
#   'tamp',
#   '##er',
#   'evident',
#   'plastic',
#   'protect',
#   '##or',
#   '.',
#   'refer',
#   'to',
#   'the',
#   'directions',
#   'for',
#   'use',
#   'of',
#   'the',
#   'container',
#   '.',
#   'clinical',
#   'pharmacology',
#   'lidocaine',
#   'hydrochloride',
#   'exerts',
#   'an',
#   'anti',
#   '##arrhyth',
#   '##mic',
#   'effect',
#   'by',
#   'increasing',
#   'the',
#   'electric',
#   'stimulation',
#   'threshold',
#   'of',
#   'the',
#   'ventricle',
#   'during',
#   'diastole',
#   '.',
#   'in',
#   'usual',
#   'therapeutic',
#   'doses',
#   ',',
#   'lidocaine',
#   'hydrochloride',
#   'produces',
#   'no',
#   'change',
#   'in',
#   'myocardial',
#   'contractility',
#   ',',
#   'in',
#   'systemic',
#   'arterial',
#   'pressure',
#   ',',
#   'or',
#   'in',
#   'absolute',
#   'refractory',
#   'period',
#   '.',
#   'about',
#   '90',
#   '%',
#   'of',
#   'an',
#   'administered',
#   'dose',
#   'of',
#   'the',
#   'drug',
#   'is',
#   'metabolized',
#   'in',
#   'the',
#   'liver',
#   '.',
#   'the',
#   'remaining',
#   '10',
#   '%',
#   'is',
#   'excreted',
#   'unchanged',
#   'via',
#   'the',
#   'kidneys',
#   '.',
#   'lidocaine',
#   'toxicity',
#   'is',
#   'related',
#   'to',
#   'systemic',
#   'blood',
#   'levels',
#   '.',
#   'the',
#   'decreased',
#   'clearance',
#   'and',
#   'longer',
#   'half',
#   '-',
#   'life',
#   'of',
#   'lidocaine',
#   'should',
#   'be',
#   'taken',
#   'into',
#   'consideration',
#   'with',
#   'prolonged',
#   '(',
#   '24',
#   'hour',
#   ')',
#   'infusions',
#   '.',
#   'constant',
#   'rate',
#   'of',
#   'infusion',
#   'may',
#   'result',
#   'in',
#   'toxic',
#   'accumulation',
#   'of',
#   'lidocaine',
#   '.',
#   'infusion',
#   'should',
#   'be',
#   'reduced',
#   'to',
#   'approximately',
#   'one',
#   '-',
#   'half',
#   'to',
#   'compensate',
#   'for',
#   'decreased',
#   'rate',
#   'of',
#   'clearance',
#   'and',
#   'concomitant',
#   'or',
#   'prior',
#   'administration',
#   'of',
#   'propranolol',
#   'may',
#   'further',
#   'increase',
#   'blood',
#   'concentrations',
#   'by',
#   'as',
#   'much',
#   'as',
#   '30',
#   '%',
#   'in',
#   'patients',
#   'without',
#   'cardiac',
#   'or',
#   'hepatic',
#   'failure',
#   '.',
#   'in',
#   'clinical',
#   'studies',
#   ',',
#   'patients',
#   'over',
#   '65',
#   'years',
#   'showed',
#   'decreased',
#   'lidocaine',
#   'clearance',
#   '.',
#   'this',
#   'was',
#   'partly',
#   'due',
#   'to',
#   'the',
#   'tendency',
#   'of',
#   'elderly',
#   'patients',
#   'to',
#   'have',
#   'lower',
#   'body',
#   'weight',
#   'and',
#   'the',
#   'increased',
#   'risk',
#   'of',
#   'cardiac',
#   'failure',
#   'in',
#   'these',
#   'patients',
#   '.',
#   'this',
#   'solution',
#   'provides',
#   'approximately',
#   '170',
#   'calories',
#   'per',
#   'liter',
#   '.',
#   'indications',
#   'and',
#   'usage',
#   'lidocaine',
#   'hydrochloride',
#   'administered',
#   'intravenously',
#   'is',
#   'specifically',
#   'indicated',
#   'in',
#   'the',
#   'acute',
#   'management',
#   'of',
#   '(',
#   '1',
#   ')',
#   'ventricular',
#   'arrhythmias',
#   'occurring',
#   'during',
#   'cardiac',
#   'manipulations',
#   ',',
#   'such',
#   'as',
#   'cardiac',
#   'surgery',
#   'and',
#   '(',
#   '2',
#   ')',
#   'life',
#   '-',
#   'threatening',
#   'arrhythmias',
#   'which',
#   'are',
#   'ventricular',
#   'in',
#   'origin',
#   ',',
#   'such',
#   'as',
#   'occur',
#   'during',
#   'acute',
#   'myocardial',
#   'infarction',
#   '.',
#   'contraindications',
#   'lidocaine',
#   'hydrochloride',
#   'is',
#   'contraind',
#   '##icated',
#   'in',
#   'patients',
#   'with',
#   'a',
#   'known',
#   'history',
#   'of',
#   'hypersensitivity',
#   'to',
#   'local',
#   'anesthetics',
#   'of',
#   'the',
#   'amide',
#   'type',
#   '.',
#   'lidocaine',
#   'should',
#   'not',
#   'be',
#   'used',
#   'in',
#   'patients',
#   'with',
#   'stokes',
#   '-',
#   'adams',
#   'syndrome',
#   ',',
#   'wolf',
#   '##f',
#   '-',
#   'parkinson',
#   '-',
#   'white',
#   'syndrome',
#   ',',
#   'or',
#   'with',
#   'severe',
#   'degrees',
#   'of',
#   'sin',
#   '##oa',
#   '##trial',
#   ',',
#   'atrioventricular',
#   ',',
#   'or',
#   'intraventricular',
#   'block',
#   '.',
#   'solutions',
#   'containing',
#   'dextrose',
#   'may',
#   'be',
#   'contraind',
#   '##icated',
#   'in',
#   'patients',
#   'with',
#   'known',
#   'allergy',
#   'to',
#   'corn',
#   'or',
#   'corn',
#   'products',
#   '.',
#   'warning',
#   '##s',
#   'reference',
#   'id',
#   ':',
#   '46',
#   '##108',
#   '##13']}

# %% [markdown]
# ### Attempting to NER?

# %%
pipe = pipeline("token-classification", model="chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")

def get_ner_tags(text):
    return {'ner_tags' : pipe(text['tokens'])}

dataset = dataset.map(get_ner_tags) # try tqdming this dog, also is there a better way to batch this?
# Out:
# Map:   0%|          | 0/647 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
dataset
# Out:
# Dataset({
#     features: ['text', 'tokens', 'ner_tags'],
#     num_rows: 647
# })

# %%
dataset[0]['ner_tags'] # next step, choose a score threshold and filter for confidence, notion of extraction?
# Out:
# [[],
#  [{'end': 7,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.313151478767395,
#    'start': 0,
#    'word': 'plastic'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.3816811144351959,
#    'start': 0,
#    'word': 'a'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.313151478767395,
#    'start': 0,
#    'word': 'plastic'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 2,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6361506581306458,
#    'start': 0,
#    'word': 'le'}],
#  [{'end': 5,
#    'entity': 'B-DRUG',
#    'index': 3,
#    'score': 0.419985294342041,
#    'start': 2,
#    'word': 'ach'}],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.35858142375946045,
#    'start': 0,
#    'word': 'solution'}],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5007998943328857,
#    'start': 0,
#    'word': 'contact'}],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.419171005487442,
#    'start': 0,
#    'word': 'layer'}],
#  [],
#  [{'end': 1,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.3816811144351959,
#    'start': 0,
#    'word': 'a'}],
#  [{'end': 6,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.5750394463539124,
#    'start': 0,
#    'word': 'rubber'}],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.8111954927444458,
#    'start': 0,
#    'word': 'ethylene'}],
#  [],
#  [{'end': 4,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.923985481262207,
#    'start': 0,
#    'word': 'prop'},
#   {'end': 6,
#    'entity': 'B-DRUG',
#    'index': 2,
#    'score': 0.5162116885185242,
#    'start': 4,
#    'word': '##yl'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 3,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6609119772911072,
#    'start': 0,
#    'word': 'non'},
#   {'end': 4,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.44214245676994324,
#    'start': 3,
#    'word': '##t'}],
#  [{'end': 4,
#    'entity': 'B-DRUG',
#    'index': 3,
#    'score': 0.63198322057724,
#    'start': 2,
#    'word': 'ox'},
#   {'end': 6,
#    'entity': 'I-DRUG',
#    'index': 4,
#    'score': 0.3696367144584656,
#    'start': 4,
#    'word': '##ic'}],
#  [],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5208030343055725,
#    'start': 0,
#    'word': 'inert'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.35858142375946045,
#    'start': 0,
#    'word': 'solution'}],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.3816811144351959,
#    'start': 0,
#    'word': 'a'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.38381674885749817,
#    'start': 0,
#    'word': 'external'}],
#  [{'end': 3,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.3581787347793579,
#    'start': 0,
#    'word': 'air'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 10,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.46086278557777405,
#    'start': 0,
#    'word': 'protection'}],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.41473665833473206,
#    'start': 0,
#    'word': 'physical'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4639527499675751,
#    'start': 0,
#    'word': 'moisture'}],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6079026460647583,
#    'start': 0,
#    'word': 'barrier'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4419332444667816,
#    'start': 0,
#    'word': 'port'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.3816811144351959,
#    'start': 0,
#    'word': 'a'}],
#  [{'end': 3,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7690395712852478,
#    'start': 0,
#    'word': 'tam'},
#   {'end': 4,
#    'entity': 'I-DRUG',
#    'index': 2,
#    'score': 0.6749188303947449,
#    'start': 3,
#    'word': '##p'}],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.313151478767395,
#    'start': 0,
#    'word': 'plastic'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 12,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4710942804813385,
#    'start': 0,
#    'word': 'pharmacology'}],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [{'end': 13,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.8387004137039185,
#    'start': 0,
#    'word': 'hydrochloride'}],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.47520211338996887,
#    'start': 0,
#    'word': 'anti'}],
#  [{'end': 9,
#    'entity': 'I-EFFECT',
#    'index': 3,
#    'score': 0.44866785407066345,
#    'start': 2,
#    'word': 'arrhyth'}],
#  [],
#  [{'end': 6,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.48255446553230286,
#    'start': 0,
#    'word': 'effect'}],
#  [{'end': 2,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.28794652223587036,
#    'start': 0,
#    'word': 'by'}],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6045650243759155,
#    'start': 0,
#    'word': 'electric'}],
#  [{'end': 11,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.35991209745407104,
#    'start': 0,
#    'word': 'stimulation'}],
#  [],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6701027154922485,
#    'start': 0,
#    'word': 'ventricle'}],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7765231728553772,
#    'start': 0,
#    'word': 'dias'},
#   {'end': 7,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.8068875670433044,
#    'start': 4,
#    'word': '##tol'},
#   {'end': 8,
#    'entity': 'I-EFFECT',
#    'index': 3,
#    'score': 0.7035431265830994,
#    'start': 7,
#    'word': '##e'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [{'end': 13,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.8387004137039185,
#    'start': 0,
#    'word': 'hydrochloride'}],
#  [],
#  [],
#  [{'end': 6,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7771751880645752,
#    'start': 0,
#    'word': 'change'}],
#  [],
#  [{'end': 10,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7592799663543701,
#    'start': 0,
#    'word': 'myocardial'}],
#  [{'end': 13,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6789929270744324,
#    'start': 0,
#    'word': 'contractility'}],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.46615859866142273,
#    'start': 0,
#    'word': 'systemic'}],
#  [{'end': 8,
#    'entity': 'I-EFFECT',
#    'index': 1,
#    'score': 0.43312549591064453,
#    'start': 0,
#    'word': 'arterial'}],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6865917444229126,
#    'start': 0,
#    'word': 'pressure'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 10,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6693665981292725,
#    'start': 0,
#    'word': 'refractory'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.37942415475845337,
#    'start': 0,
#    'word': '%'}],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.37275803089141846,
#    'start': 0,
#    'word': 'dose'}],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.29866471886634827,
#    'start': 0,
#    'word': 'drug'}],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6103178858757019,
#    'start': 0,
#    'word': 'metabol'}],
#  [],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6938348412513733,
#    'start': 0,
#    'word': 'liver'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.37942415475845337,
#    'start': 0,
#    'word': '%'}],
#  [],
#  [{'end': 3,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6422896981239319,
#    'start': 0,
#    'word': 'exc'},
#   {'end': 8,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.6981099843978882,
#    'start': 3,
#    'word': '##reted'}],
#  [],
#  [{'end': 3,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.34730052947998047,
#    'start': 0,
#    'word': 'via'}],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6617177724838257,
#    'start': 0,
#    'word': 'kidneys'}],
#  [],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.690062403678894,
#    'start': 0,
#    'word': 'toxicity'}],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.46615859866142273,
#    'start': 0,
#    'word': 'systemic'}],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4687023460865021,
#    'start': 0,
#    'word': 'blood'}],
#  [],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5658155083656311,
#    'start': 0,
#    'word': 'decreased'}],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6543614864349365,
#    'start': 0,
#    'word': 'clearance'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4920417368412018,
#    'start': 0,
#    'word': 'life'}],
#  [],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4451114535331726,
#    'start': 0,
#    'word': 'rate'}],
#  [],
#  [],
#  [],
#  [{'end': 6,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.39708104729652405,
#    'start': 0,
#    'word': 'result'}],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6567695140838623,
#    'start': 0,
#    'word': 'toxic'}],
#  [{'end': 12,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7355515956878662,
#    'start': 0,
#    'word': 'accumulation'}],
#  [],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.47418007254600525,
#    'start': 0,
#    'word': 'reduced'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5658155083656311,
#    'start': 0,
#    'word': 'decreased'}],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4451114535331726,
#    'start': 0,
#    'word': 'rate'}],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6543614864349365,
#    'start': 0,
#    'word': 'clearance'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.9100304841995239,
#    'start': 0,
#    'word': 'prop'},
#   {'end': 7,
#    'entity': 'I-DRUG',
#    'index': 2,
#    'score': 0.738966166973114,
#    'start': 4,
#    'word': '##ran'},
#   {'end': 10,
#    'entity': 'I-DRUG',
#    'index': 3,
#    'score': 0.8515888452529907,
#    'start': 7,
#    'word': '##olo'},
#   {'end': 11,
#    'entity': 'I-DRUG',
#    'index': 4,
#    'score': 0.8607340455055237,
#    'start': 10,
#    'word': '##l'}],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6770762801170349,
#    'start': 0,
#    'word': 'increase'}],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4687023460865021,
#    'start': 0,
#    'word': 'blood'}],
#  [{'end': 14,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.3617246747016907,
#    'start': 0,
#    'word': 'concentrations'}],
#  [{'end': 2,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.28794652223587036,
#    'start': 0,
#    'word': 'by'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.37942415475845337,
#    'start': 0,
#    'word': '%'}],
#  [],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7242550849914551,
#    'start': 0,
#    'word': 'cardiac'}],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7565127015113831,
#    'start': 0,
#    'word': 'hepatic'}],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7741958498954773,
#    'start': 0,
#    'word': 'failure'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5658155083656311,
#    'start': 0,
#    'word': 'decreased'}],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6543614864349365,
#    'start': 0,
#    'word': 'clearance'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6019060611724854,
#    'start': 0,
#    'word': 'tendency'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5750138163566589,
#    'start': 0,
#    'word': 'body'}],
#  [{'end': 6,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5824403166770935,
#    'start': 0,
#    'word': 'weight'}],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5531390309333801,
#    'start': 0,
#    'word': 'increased'}],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5392974019050598,
#    'start': 0,
#    'word': 'risk'}],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7242550849914551,
#    'start': 0,
#    'word': 'cardiac'}],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7741958498954773,
#    'start': 0,
#    'word': 'failure'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.35858142375946045,
#    'start': 0,
#    'word': 'solution'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4123101234436035,
#    'start': 0,
#    'word': 'usage'}],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [{'end': 13,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.8387004137039185,
#    'start': 0,
#    'word': 'hydrochloride'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6099869608879089,
#    'start': 0,
#    'word': 'acute'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 11,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5801771283149719,
#    'start': 0,
#    'word': 'ventricular'}],
#  [{'end': 11,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7416275143623352,
#    'start': 0,
#    'word': 'arrhythmias'}],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7242550849914551,
#    'start': 0,
#    'word': 'cardiac'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7242550849914551,
#    'start': 0,
#    'word': 'cardiac'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4920417368412018,
#    'start': 0,
#    'word': 'life'}],
#  [],
#  [{'end': 11,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5387974381446838,
#    'start': 0,
#    'word': 'threatening'}],
#  [{'end': 11,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7416275143623352,
#    'start': 0,
#    'word': 'arrhythmias'}],
#  [],
#  [],
#  [{'end': 11,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5801771283149719,
#    'start': 0,
#    'word': 'ventricular'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6099869608879089,
#    'start': 0,
#    'word': 'acute'}],
#  [{'end': 10,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7592799663543701,
#    'start': 0,
#    'word': 'myocardial'}],
#  [{'end': 10,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.81267911195755,
#    'start': 0,
#    'word': 'infarction'}],
#  [],
#  [{'end': 11,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.48205116391181946,
#    'start': 8,
#    'word': '##dic'}],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [{'end': 13,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.8387004137039185,
#    'start': 0,
#    'word': 'hydrochloride'}],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4152587056159973,
#    'start': 0,
#    'word': 'contrain'},
#   {'end': 9,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.6700116991996765,
#    'start': 8,
#    'word': '##d'}],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 1,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.3816811144351959,
#    'start': 0,
#    'word': 'a'}],
#  [],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.8317620158195496,
#    'start': 0,
#    'word': 'hypersen'},
#   {'end': 16,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.8940280675888062,
#    'start': 8,
#    'word': '##sitivity'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 5,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.35272470116615295,
#    'start': 0,
#    'word': 'amide'}],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6058723330497742,
#    'start': 0,
#    'word': 'type'}],
#  [],
#  [{'end': 9,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.7405717372894287,
#    'start': 0,
#    'word': 'lidocaine'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 6,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.573072612285614,
#    'start': 0,
#    'word': 'stokes'}],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.5824033617973328,
#    'start': 0,
#    'word': 'adams'}],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.8226820230484009,
#    'start': 0,
#    'word': 'syndrome'}],
#  [],
#  [{'end': 4,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6982423663139343,
#    'start': 0,
#    'word': 'wolf'}],
#  [],
#  [],
#  [{'end': 9,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7646835446357727,
#    'start': 0,
#    'word': 'parkinson'}],
#  [],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6706604361534119,
#    'start': 0,
#    'word': 'white'}],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.8226820230484009,
#    'start': 0,
#    'word': 'syndrome'}],
#  [],
#  [],
#  [],
#  [{'end': 6,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.619722306728363,
#    'start': 0,
#    'word': 'severe'}],
#  [{'end': 7,
#    'entity': 'I-EFFECT',
#    'index': 1,
#    'score': 0.33232948184013367,
#    'start': 0,
#    'word': 'degrees'}],
#  [],
#  [{'end': 3,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.43270406126976013,
#    'start': 0,
#    'word': 'sin'}],
#  [],
#  [],
#  [],
#  [{'end': 3,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7804836630821228,
#    'start': 0,
#    'word': 'atr'},
#   {'end': 5,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.8897386193275452,
#    'start': 3,
#    'word': '##io'},
#   {'end': 16,
#    'entity': 'I-EFFECT',
#    'index': 3,
#    'score': 0.894463062286377,
#    'start': 5,
#    'word': '##ventricular'}],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.721727728843689,
#    'start': 0,
#    'word': 'intraven'},
#   {'end': 12,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.8784604072570801,
#    'start': 8,
#    'word': '##tric'},
#   {'end': 16,
#    'entity': 'I-EFFECT',
#    'index': 3,
#    'score': 0.8283998370170593,
#    'start': 12,
#    'word': '##ular'}],
#  [{'end': 5,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6960836052894592,
#    'start': 0,
#    'word': 'block'}],
#  [],
#  [],
#  [],
#  [{'end': 4,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.8507484197616577,
#    'start': 0,
#    'word': 'dext'},
#   {'end': 8,
#    'entity': 'I-DRUG',
#    'index': 2,
#    'score': 0.6767453551292419,
#    'start': 4,
#    'word': '##rose'}],
#  [],
#  [],
#  [{'end': 8,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.4152587056159973,
#    'start': 0,
#    'word': 'contrain'},
#   {'end': 9,
#    'entity': 'I-EFFECT',
#    'index': 2,
#    'score': 0.6700116991996765,
#    'start': 8,
#    'word': '##d'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 7,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.7761352062225342,
#    'start': 0,
#    'word': 'allergy'}],
#  [],
#  [{'end': 4,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.715204119682312,
#    'start': 0,
#    'word': 'corn'}],
#  [],
#  [{'end': 4,
#    'entity': 'B-DRUG',
#    'index': 1,
#    'score': 0.715204119682312,
#    'start': 0,
#    'word': 'corn'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'end': 2,
#    'entity': 'B-EFFECT',
#    'index': 1,
#    'score': 0.6519659161567688,
#    'start': 0,
#    'word': 'id'}],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# From this output, I think I am running the pipe incorrectly, I think I should be running the pipe on the whole text as opposed to the individual tokens, as the index field seems to always be the same lists of one?

# %%
# Try 2
pipe = pipeline("token-classification", model="chintagunta85/electramed-small-ADE-DRUG-EFFECT-ner-v3")

def get_ner_tags_again(text):
    return {'ner_tags_again' : pipe(text['text'])}

dataset = dataset.map(get_ner_tags_again) # try tqdming this dog, also is there a better way to batch this?
# Out:
# Map:   0%|          | 0/647 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/4264473454.py:7 in <cell │
# │ line: 7>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/4264473454.py'          │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:578 in wrapper                                                                         │
# │                                                                                           │
# │    575 │   │   else:                                                                      │
# │    576 │   │   │   self: "Dataset" = kwargs.pop("self")                                   │
# │    577 │   │   # apply actual function                                                    │
# │ ❱  578 │   │   out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)         │
# │    579 │   │   datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) el │
# │    580 │   │   for dataset in datasets:                                                   │
# │    581 │   │   │   # Remove task templates if a column mapping of the template is no long │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:543 in wrapper                                                                         │
# │                                                                                           │
# │    540 │   │   │   "output_all_columns": self._output_all_columns,                        │
# │    541 │   │   }                                                                          │
# │    542 │   │   # apply actual function                                                    │
# │ ❱  543 │   │   out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)         │
# │    544 │   │   datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) el │
# │    545 │   │   # re-apply format to the output                                            │
# │    546 │   │   for dataset in datasets:                                                   │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3073 in map                                                                            │
# │                                                                                           │
# │   3070 │   │   │   │   │   leave=False,                                                   │
# │   3071 │   │   │   │   │   desc=desc or "Map",                                            │
# │   3072 │   │   │   │   ) as pbar:                                                         │
# │ ❱ 3073 │   │   │   │   │   for rank, done, content in Dataset._map_single(**dataset_kwarg │
# │   3074 │   │   │   │   │   │   if done:                                                   │
# │   3075 │   │   │   │   │   │   │   shards_done += 1                                       │
# │   3076 │   │   │   │   │   │   │   logger.debug(f"Finished processing shard number {rank} │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3427 in _map_single                                                                    │
# │                                                                                           │
# │   3424 │   │   │   │   if not batched:                                                    │
# │   3425 │   │   │   │   │   _time = time.time()                                            │
# │   3426 │   │   │   │   │   for i, example in shard_iterable:                              │
# │ ❱ 3427 │   │   │   │   │   │   example = apply_function_on_filtered_inputs(example, i, of │
# │   3428 │   │   │   │   │   │   if update_data:                                            │
# │   3429 │   │   │   │   │   │   │   if i == 0:                                             │
# │   3430 │   │   │   │   │   │   │   │   buf_writer, writer, tmp_file = init_buffer_and_wri │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3330 in apply_function_on_filtered_inputs                                              │
# │                                                                                           │
# │   3327 │   │   │   │   additional_args += (effective_indices,)                            │
# │   3328 │   │   │   if with_rank:                                                          │
# │   3329 │   │   │   │   additional_args += (rank,)                                         │
# │ ❱ 3330 │   │   │   processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)   │
# │   3331 │   │   │   if isinstance(processed_inputs, LazyDict):                             │
# │   3332 │   │   │   │   processed_inputs = {                                               │
# │   3333 │   │   │   │   │   k: v for k, v in processed_inputs.data.items() if k not in pro │
# │                                                                                           │
# │ /var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/4264473454.py:5 in       │
# │ get_ner_tags_again                                                                        │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/4264473454.py'          │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/pipelines/ │
# │ token_classification.py:216 in __call__                                                   │
# │                                                                                           │
# │   213 │   │   if offset_mapping:                                                          │
# │   214 │   │   │   kwargs["offset_mapping"] = offset_mapping                               │
# │   215 │   │                                                                               │
# │ ❱ 216 │   │   return super().__call__(inputs, **kwargs)                                   │
# │   217 │                                                                                   │
# │   218 │   def preprocess(self, sentence, offset_mapping=None):                            │
# │   219 │   │   truncation = True if self.tokenizer.model_max_length and self.tokenizer.mod │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/pipelines/ │
# │ base.py:1087 in __call__                                                                  │
# │                                                                                           │
# │   1084 │   │   │   │   )                                                                  │
# │   1085 │   │   │   )                                                                      │
# │   1086 │   │   else:                                                                      │
# │ ❱ 1087 │   │   │   return self.run_single(inputs, preprocess_params, forward_params, post │
# │   1088 │                                                                                  │
# │   1089 │   def run_multi(self, inputs, preprocess_params, forward_params, postprocess_par │
# │   1090 │   │   return [self.run_single(item, preprocess_params, forward_params, postproce │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/pipelines/ │
# │ base.py:1094 in run_single                                                                │
# │                                                                                           │
# │   1091 │                                                                                  │
# │   1092 │   def run_single(self, inputs, preprocess_params, forward_params, postprocess_pa │
# │   1093 │   │   model_inputs = self.preprocess(inputs, **preprocess_params)                │
# │ ❱ 1094 │   │   model_outputs = self.forward(model_inputs, **forward_params)               │
# │   1095 │   │   outputs = self.postprocess(model_outputs, **postprocess_params)            │
# │   1096 │   │   return outputs                                                             │
# │   1097                                                                                    │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/pipelines/ │
# │ base.py:995 in forward                                                                    │
# │                                                                                           │
# │    992 │   │   │   │   inference_context = self.get_inference_context()                   │
# │    993 │   │   │   │   with inference_context():                                          │
# │    994 │   │   │   │   │   model_inputs = self._ensure_tensor_on_device(model_inputs, dev │
# │ ❱  995 │   │   │   │   │   model_outputs = self._forward(model_inputs, **forward_params)  │
# │    996 │   │   │   │   │   model_outputs = self._ensure_tensor_on_device(model_outputs, d │
# │    997 │   │   │   else:                                                                  │
# │    998 │   │   │   │   raise ValueError(f"Framework {self.framework} is not supported")   │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/pipelines/ │
# │ token_classification.py:242 in _forward                                                   │
# │                                                                                           │
# │   239 │   │   if self.framework == "tf":                                                  │
# │   240 │   │   │   logits = self.model(model_inputs.data)[0]                               │
# │   241 │   │   else:                                                                       │
# │ ❱ 242 │   │   │   logits = self.model(**model_inputs)[0]                                  │
# │   243 │   │                                                                               │
# │   244 │   │   return {                                                                    │
# │   245 │   │   │   "logits": logits,                                                       │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/torch/nn/modules/module │
# │ .py:1194 in _call_impl                                                                    │
# │                                                                                           │
# │   1191 │   │   # this function, and just call forward.                                    │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_h │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):            │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                  │
# │   1195 │   │   # Do not call functions when jit is used                                   │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                      │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                         │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/models/ele │
# │ ctra/modeling_electra.py:1299 in forward                                                  │
# │                                                                                           │
# │   1296 │   │   """                                                                        │
# │   1297 │   │   return_dict = return_dict if return_dict is not None else self.config.use_ │
# │   1298 │   │                                                                              │
# │ ❱ 1299 │   │   discriminator_hidden_states = self.electra(                                │
# │   1300 │   │   │   input_ids,                                                             │
# │   1301 │   │   │   attention_mask=attention_mask,                                         │
# │   1302 │   │   │   token_type_ids=token_type_ids,                                         │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/torch/nn/modules/module │
# │ .py:1194 in _call_impl                                                                    │
# │                                                                                           │
# │   1191 │   │   # this function, and just call forward.                                    │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_h │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):            │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                  │
# │   1195 │   │   # Do not call functions when jit is used                                   │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                      │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                         │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/models/ele │
# │ ctra/modeling_electra.py:907 in forward                                                   │
# │                                                                                           │
# │    904 │   │                                                                              │
# │    905 │   │   head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)   │
# │    906 │   │                                                                              │
# │ ❱  907 │   │   hidden_states = self.embeddings(                                           │
# │    908 │   │   │   input_ids=input_ids,                                                   │
# │    909 │   │   │   position_ids=position_ids,                                             │
# │    910 │   │   │   token_type_ids=token_type_ids,                                         │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/torch/nn/modules/module │
# │ .py:1194 in _call_impl                                                                    │
# │                                                                                           │
# │   1191 │   │   # this function, and just call forward.                                    │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_h │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):            │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                  │
# │   1195 │   │   # Do not call functions when jit is used                                   │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                      │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                         │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/transformers/models/ele │
# │ ctra/modeling_electra.py:207 in forward                                                   │
# │                                                                                           │
# │    204 │   │   embeddings = inputs_embeds + token_type_embeddings                         │
# │    205 │   │   if self.position_embedding_type == "absolute":                             │
# │    206 │   │   │   position_embeddings = self.position_embeddings(position_ids)           │
# │ ❱  207 │   │   │   embeddings += position_embeddings                                      │
# │    208 │   │   embeddings = self.LayerNorm(embeddings)                                    │
# │    209 │   │   embeddings = self.dropout(embeddings)                                      │
# │    210 │   │   return embeddings                                                          │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: The size of tensor a (1372) must match the size of tensor b (512) at
# non-singleton dimension 1

# %% [markdown]
# This might not be correct, tensor length mismatch. This probably means things need to be split down and padded before hand. Would the workflow be separate out doc to sentences, then pipe the sentences? This is a TO DO

# %% [markdown]
# ### Try out some filter thresholds

# %%
dataset_50 = 
# dataset_80 = 
# dataset_95 =
# Out:
# Filter:   0%|          | 0/647 [00:00<?, ? examples/s]
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/3357191444.py:1 in <cell │
# │ line: 1>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/3357191444.py'          │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:543 in wrapper                                                                         │
# │                                                                                           │
# │    540 │   │   │   "output_all_columns": self._output_all_columns,                        │
# │    541 │   │   }                                                                          │
# │    542 │   │   # apply actual function                                                    │
# │ ❱  543 │   │   out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)         │
# │    544 │   │   datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) el │
# │    545 │   │   # re-apply format to the output                                            │
# │    546 │   │   for dataset in datasets:                                                   │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/fingerprint.py │
# │ :511 in wrapper                                                                           │
# │                                                                                           │
# │   508 │   │   │                                                                           │
# │   509 │   │   │   # Call actual function                                                  │
# │   510 │   │   │                                                                           │
# │ ❱ 511 │   │   │   out = func(dataset, *args, **kwargs)                                    │
# │   512 │   │   │                                                                           │
# │   513 │   │   │   # Update fingerprint of in-place transforms + update in-place history o │
# │   514                                                                                     │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3600 in filter                                                                         │
# │                                                                                           │
# │   3597 │   │   if len(self) == 0:                                                         │
# │   3598 │   │   │   return self                                                            │
# │   3599 │   │                                                                              │
# │ ❱ 3600 │   │   indices = self.map(                                                        │
# │   3601 │   │   │   function=partial(                                                      │
# │   3602 │   │   │   │   get_indices_from_mask_function, function, batched, with_indices, i │
# │   3603 │   │   │   ),                                                                     │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:578 in wrapper                                                                         │
# │                                                                                           │
# │    575 │   │   else:                                                                      │
# │    576 │   │   │   self: "Dataset" = kwargs.pop("self")                                   │
# │    577 │   │   # apply actual function                                                    │
# │ ❱  578 │   │   out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)         │
# │    579 │   │   datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) el │
# │    580 │   │   for dataset in datasets:                                                   │
# │    581 │   │   │   # Remove task templates if a column mapping of the template is no long │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:543 in wrapper                                                                         │
# │                                                                                           │
# │    540 │   │   │   "output_all_columns": self._output_all_columns,                        │
# │    541 │   │   }                                                                          │
# │    542 │   │   # apply actual function                                                    │
# │ ❱  543 │   │   out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)         │
# │    544 │   │   datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) el │
# │    545 │   │   # re-apply format to the output                                            │
# │    546 │   │   for dataset in datasets:                                                   │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3073 in map                                                                            │
# │                                                                                           │
# │   3070 │   │   │   │   │   leave=False,                                                   │
# │   3071 │   │   │   │   │   desc=desc or "Map",                                            │
# │   3072 │   │   │   │   ) as pbar:                                                         │
# │ ❱ 3073 │   │   │   │   │   for rank, done, content in Dataset._map_single(**dataset_kwarg │
# │   3074 │   │   │   │   │   │   if done:                                                   │
# │   3075 │   │   │   │   │   │   │   shards_done += 1                                       │
# │   3076 │   │   │   │   │   │   │   logger.debug(f"Finished processing shard number {rank} │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3449 in _map_single                                                                    │
# │                                                                                           │
# │   3446 │   │   │   │   │   │   │   range(*(slice(i, i + batch_size).indices(shard.num_row │
# │   3447 │   │   │   │   │   │   )  # Something simpler?                                    │
# │   3448 │   │   │   │   │   │   try:                                                       │
# │ ❱ 3449 │   │   │   │   │   │   │   batch = apply_function_on_filtered_inputs(             │
# │   3450 │   │   │   │   │   │   │   │   batch,                                             │
# │   3451 │   │   │   │   │   │   │   │   indices,                                           │
# │   3452 │   │   │   │   │   │   │   │   check_same_num_examples=len(shard.list_indexes())  │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:3330 in apply_function_on_filtered_inputs                                              │
# │                                                                                           │
# │   3327 │   │   │   │   additional_args += (effective_indices,)                            │
# │   3328 │   │   │   if with_rank:                                                          │
# │   3329 │   │   │   │   additional_args += (rank,)                                         │
# │ ❱ 3330 │   │   │   processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)   │
# │   3331 │   │   │   if isinstance(processed_inputs, LazyDict):                             │
# │   3332 │   │   │   │   processed_inputs = {                                               │
# │   3333 │   │   │   │   │   k: v for k, v in processed_inputs.data.items() if k not in pro │
# │                                                                                           │
# │ /Users/mjc014/.pyenv/versions/3.10.4/lib/python3.10/site-packages/datasets/arrow_dataset. │
# │ py:6134 in get_indices_from_mask_function                                                 │
# │                                                                                           │
# │   6131 │   │   │   for i in range(num_examples):                                          │
# │   6132 │   │   │   │   example = {key: batch[key][i] for key in batch}                    │
# │   6133 │   │   │   │   mask.append(                                                       │
# │ ❱ 6134 │   │   │   │   │   function(example, indices[i], **fn_kwargs) if with_indices els │
# │   6135 │   │   │   │   )                                                                  │
# │   6136 │   │   else:                                                                      │
# │   6137 │   │   │   # inputs is a list of columns                                          │
# │                                                                                           │
# │ /var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/3357191444.py:1 in       │
# │ <lambda>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/m6/b6y4g9114836jky8p81w12mchscvrj/T/ipykernel_24266/3357191444.py'          │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: list indices must be integers or slices, not str

# %%
dataset_50 = []
dataset_80 = []
dataset_95 = []

for entry in dataset:
    for ner_tags in entry['ner_tags']:
        try:
            if ner_tags[0]['score'] > 0.50:
                dataset_50.append()
            if ner_tags[0]['score'] > 0.80:
                print(ner_tags[0])
            if ner_tags[0]['score'] > 0.95:
                print(ner_tags[0])

            else:
                pass
        except:
            pass
# Out:
# {'end': 8, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8111954927444458, 'start': 0, 'word': 'ethylene'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7690395712852478, 'start': 0, 'word': 'tam'}
# {'end': 13, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8387004137039185, 'start': 0, 'word': 'hydrochloride'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7765231728553772, 'start': 0, 'word': 'dias'}
# {'end': 13, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8387004137039185, 'start': 0, 'word': 'hydrochloride'}
# {'end': 6, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7771751880645752, 'start': 0, 'word': 'change'}
# {'end': 10, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7592799663543701, 'start': 0, 'word': 'myocardial'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9100304841995239, 'start': 0, 'word': 'prop'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7565127015113831, 'start': 0, 'word': 'hepatic'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7741958498954773, 'start': 0, 'word': 'failure'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7741958498954773, 'start': 0, 'word': 'failure'}
# {'end': 13, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8387004137039185, 'start': 0, 'word': 'hydrochloride'}
# {'end': 10, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7592799663543701, 'start': 0, 'word': 'myocardial'}
# {'end': 10, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.81267911195755, 'start': 0, 'word': 'infarction'}
# {'end': 13, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8387004137039185, 'start': 0, 'word': 'hydrochloride'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8317620158195496, 'start': 0, 'word': 'hypersen'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8226820230484009, 'start': 0, 'word': 'syndrome'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7646835446357727, 'start': 0, 'word': 'parkinson'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8226820230484009, 'start': 0, 'word': 'syndrome'}
# {'end': 3, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7804836630821228, 'start': 0, 'word': 'atr'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8507484197616577, 'start': 0, 'word': 'dext'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.
}
# {'end': 3, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7513657212257385, 'start': 0, 'word': 'non'}
# {'end': 5, 'entity': 'B-DRUG', 'index': 3, 'score': 0.9022899866104126, 'start': 2, 'word': 'ami'}
# {'end': 3, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7938096523284912, 'start': 0, 'word': 'cvd'}
# {'end': 2, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7528230547904968, 'start': 0, 'word': '01'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9241032004356384, 'start': 0, 'word': 'min'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9241032004356384, 'start': 0, 'word': 'min'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9241032004356384, 'start': 0, 'word': 'min'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9241032004356384, 'start': 0, 'word': 'min'}
# {'end': 5, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8763837814331055, 'start': 0, 'word': 'anthr'}
# {'end': 6, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8591823577880859, 'start': 0, 'word': 'granul'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.768801748752594, 'start': 0, 'word': 'camp'}
# {'end': 2, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7528230547904968, 'start': 0, 'word': '01'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9241032004356384, 'start': 0, 'word': 'min'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9241032004356384, 'start': 0, 'word': 'min'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8061672449111938, 'start': 0, 'word': 'fever'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8061672449111938, 'start': 0, 'word': 'fever'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8061672449111938, 'start': 0, 'word': 'fever'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8061672449111938, 'start': 0, 'word': 'fever'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8788987994194031, 'start': 0, 'word': 'orn'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7889112830162048, 'start': 0, 'word': 'trac'}
# {'end': 3, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8325650095939636, 'start': 0, 'word': 'rel'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8061672449111938, 'start': 0, 'word': 'fever'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.832242488861084, 'start': 0, 'word': 'bor'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8008946180343628, 'start': 0, 'word': 'cholera'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.768801748752594, 'start': 0, 'word': 'camp'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.768801748752594, 'start': 0, 'word': 'camp'}
# {'end': 12, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7914355397224426, 'start': 0, 'word': 'streptomycin'}
# {'end': 6, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8591823577880859, 'start': 0, 'word': 'granul'}
# {'end': 6, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8591823577880859, 'start': 0, 'word': 'granul'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7578825354576111, 'start': 0, 'word': 'addiction'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7578825354576111, 'start': 0, 'word': 'addiction'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7742463946342468, 'start': 0, 'word': 'abuse'}
# {'end': 10, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7560016512870789, 'start': 0, 'word': 'depression'}
# {'end': 3, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7875754833221436, 'start': 0, 'word': 'dep'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8226820230484009, 'start': 0, 'word': 'syndrome'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8075074553489685, 'start': 0, 'word': 'hepatitis'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7565127015113831, 'start': 0, 'word': 'hepatic'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8317620158195496, 'start': 0, 'word': 'hypersen'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7565127015113831, 'start': 0, 'word': 'hepatic'}
# {'end': 11, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7509438395500183, 'start': 0, 'word': 'hypotension'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7565127015113831, 'start': 0, 'word': 'hepatic'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7559230923652649, 'start': 0, 'word': 'renal'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7742463946342468, 'start': 0, 'word': 'abuse'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7742463946342468, 'start': 0, 'word': 'abuse'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 2, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8284983038902283, 'start': 0, 'word': '45'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7578825354576111, 'start': 0, 'word': 'addiction'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7578825354576111, 'start': 0, 'word': 'addiction'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9207221269607544, 'start': 0, 'word': 'bup'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9207221269607544, 'start': 0, 'word': 'bup'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9025924801826477, 'start': 0, 'word': 'nal'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9207221269607544, 'start': 0, 'word': 'bup'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9025924801826477, 'start': 0, 'word': 'nal'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9207221269607544, 'start': 0, 'word': 'bup'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9025924801826477, 'start': 0, 'word': 'nal'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9207221269607544, 'start': 0, 'word': 'bup'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.9025924801826477, 'start': 0, 'word': 'nal'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7922825217247009, 'start': 0, 'word': 'swallow'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 3, 'score': 0.8899095058441162, 'start': 2, 'word': 'ox'}
# {'end': 10, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7830885052680969, 'start': 0, 'word': 'swallowing'}
# {'end': 2, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8284983038902283, 'start': 0, 'word': '45'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7789992094039917, 'start': 0, 'word': 'prostate'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7789992094039917, 'start': 0, 'word': 'prostate'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7922825217247009, 'start': 0, 'word': 'swallow'}
# {'end': 5, 'entity': 'B-DRUG', 'index': 1, 'score': 0.755169153213501, 'start': 0, 'word': 'gonad'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7831774353981018, 'start': 0, 'word': 'fractures'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.803139865398407, 'start': 0, 'word': 'fracture'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7609103918075562, 'start': 0, 'word': 'falls'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7901243567466736, 'start': 0, 'word': 'fall'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8197067975997925, 'start': 0, 'word': 'seizure'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8197067975997925, 'start': 0, 'word': 'seizure'}
# {'end': 1, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8260549902915955, 'start': 0, 'word': '≥'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7635996341705322, 'start': 0, 'word': 'fatigue'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8105027079582214, 'start': 0, 'word': 'rash'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7622033357620239, 'start': 0, 'word': 'appetite'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7901243567466736, 'start': 0, 'word': 'fall'}
# {'end': 12, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7545614242553711, 'start': 0, 'word': 'hypertension'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8142182230949402, 'start': 0, 'word': 'diarrhea'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.803139865398407, 'start': 0, 'word': 'fracture'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.826352059841156, 'start': 0, 'word': 'med'}
# {'end': 2, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8617372512817383, 'start': 0, 'word': 'oa'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7653083801269531, 'start': 0, 'word': 'loss'}
# {'end': 9, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7831774353981018, 'start': 0, 'word': 'fractures'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7609103918075562, 'start': 0, 'word': 'falls'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8197067975997925, 'start': 0, 'word': 'seizure'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7789992094039917, 'start': 0, 'word': 'prostate'}
# {'end': 8, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7789992094039917, 'start': 0, 'word': 'prostate'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7922825217247009, 'start': 0, 'word': 'swallow'}
# {'end': 5, 'entity': 'B-DRUG', 'index': 1, 'score': 0.755169153213501, 'start': 0, 'word': 'gonad'}
# {'end': 2, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7752197980880737, 'start': 0, 'word': 'ar'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8049511313438416, 'start': 0, 'word': 'death'}
# {'end': 12, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7545614242553711, 'start': 0, 'word': 'hypertension'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7741958498954773, 'start': 0, 'word': 'failure'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8045681715011597, 'start': 0, 'word': 'fatal'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 7, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7565127015113831, 'start': 0, 'word': 'hepatic'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8082176446914673, 'start': 0, 'word': 'meth'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8511133193969727, 'start': 0, 'word': 'hyper'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 3, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.757846474647522, 'start': 0, 'word': 'bit'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7543765306472778, 'start': 0, 'word': 'taste'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8020930290222168, 'start': 0, 'word': 'doc'}
# {'end': 6, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7793434858322144, 'start': 0, 'word': 'sodium'}
# {'end': 9, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7531009912490845, 'start': 0, 'word': 'magnesium'}
# {'end': 6, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7793434858322144, 'start': 0, 'word': 'sodium'}
# {'end': 6, 'entity': 'B-DRUG', 'index': 1, 'score': 0.7793434858322144, 'start': 0, 'word': 'sodium'}
# {'end': 6, 'entity': 'B-DRUG', 'index': 1, 'score': 0.837146520614624, 'start': 0, 'word': 'glycol'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8511133193969727, 'start': 0, 'word': 'hyper'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8469196557998657, 'start': 0, 'word': 'thy'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7699417471885681, 'start': 0, 'word': 'mouth'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 3, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8469196557998657, 'start': 0, 'word': 'thy'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.923985481262207, 'start': 0, 'word': 'prop'}
# {'end': 4, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8166556358337402, 'start': 0, 'word': 'grav'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8511133193969727, 'start': 0, 'word': 'hyper'}
# {'end': 2, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.7843839526176453, 'start': 0, 'word': 'go'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8082176446914673, 'start': 0, 'word': 'meth'}
# {'end': 5, 'entity': 'B-EFFECT', 'index': 1, 'score': 0.8511133193969727, 'start': 0, 'word': 'hyper'}
# {'end': 4, 'entity': 'B-DRUG', 'index': 1, 'score': 0.8082176446914673, 'start': 0, 'word': 'meth'}

# %% [markdown]
# The problem of padding needs to be addressed and pipe needs to be correctly run. Analysis is impossible on this set as compound chemicals / phenotypes are being split up and evaluated separately when they should be together.
