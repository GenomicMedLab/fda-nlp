# %%
import pandas as pd

# %% [markdown]
# ## Manual Assessment of Correctness
# This is a simple python workflow to assess correctness for therapeutic outcomes identified through use of the *outlines* package to enforce strict schemas for LLM responses. In short, for each trial the datasets are loaded and the field experted is prompted with the identified outcomes/values alongside the original text. The field expert is expected to identify whether the outcomes/values are factually correct against the original text and provide the block of text that supports the answer. Additionally, the user should make note of any trends or oddities noticed in responses.

# %% [markdown]
# ### Trial 1: Mistral-7b-Instruct-v0.3, JSON Schema
# Load data

# %%
# file_name = ['20240607_llm-mistral.xlsx']
# df = pd.read_excel(file_name[0]).drop(labels='Unnamed: 0',axis=1)

df = pd.read_excel('20240607_mistralTrialEval-inProgress.xlsx').drop(labels='Unnamed: 0',axis=1)

df[0:5]
# Out:
#                                           outcome  \
# 0  Hamilton Depression Rating Scale (total score)
# 1                                  Pain reduction
# 2                                    Success rate
# 3                                overall survival
# 4                       incidence of endometritis
#
#                                                value  \
# 0                  significantly superior to placebo
# 1                               greater than placebo
# 2  Proportion of subjects with a-0 (clear) or 1 (...
# 3  12.1 for pemetrexed for injection plus cisplat...
# 4                                  27.6% for placebo
#
#                                          study_group  \
# 0                                        venlafaxine
# 1  Duloxetine delayed-release capsules in Major D...
# 2               Clobetasol propionate shampoo, 0.05%
# 3  pemetrexed for injection plus cisplatin is com...
# 4                 a group given placebo in the trial
#
#                    brand_name application_number  \
# 0                 venlafaxine         ANDA090555
# 1  Duloxetine Delayed-Release         ANDA203088
# 2       clobetasol propionate         ANDA090974
# 3                  Pemetrexed         ANDA204890
# 4                   Cefoxitin         ANDA065415
#
#                                     clinical_studies assessment  \
# 0  CLINICAL TRIALS The efficacy of venlafaxine hy...        Yes
# 1  14 CLINICAL STUDIES 14.1 Overview of the Clini...        Yes
# 2  14 CLINICAL STUDIES The safety and efficacy of...         No
# 3  14 CLINICAL STUDIES 14.1 Non-Squamous NSCLC In...        Yes
# 4  CLINICAL STUDIES A prospective, randomized, do...        Yes
#
#                                                notes
# 0  Correct but not specific: In these 5 studies, ...
# 1  After 13 weeks of treatment, patients taking D...
# 2                        Definition for success rate
# 3  Efficacy Parameter All Randomized and Treated ...
# 4  Endometritis occurred in 16/58 (27.6%) patient...

# %%
# Inspection Block
df = pd.read_excel('20240607_mistralTrialEval.xlsx').drop(labels='Unnamed: 0',axis=1)

df[0:15]
# Out:
#                                            outcome  \
# 0   Hamilton Depression Rating Scale (total score)
# 1                                   Pain reduction
# 2                                     Success rate
# 3                                 overall survival
# 4                        incidence of endometritis
# 5                                   dec_flare_rate
# 6                               clinical cure rate
# 7                                  stool frequency
# 8                   Additional Therapeutic Outcome
# 9                       Rate of clinical remission
# 10                              Clinical Cure Rate
# 11                             HbA1C (%) reduction
# 12                        Blood Pressure Reduction
# 13               Reduction of Ashworth Scale score
# 14                            Change in PUQE score
#
#                                                 value  \
# 0                   significantly superior to placebo
# 1                                greater than placebo
# 2   Proportion of subjects with a-0 (clear) or 1 (...
# 3   12.1 for pemetrexed for injection plus cisplat...
# 4                                   27.6% for placebo
# 5                  decreased frequency of gout flares
# 6                                             183/186
# 7                                         improvement
# 8                       mild to moderate hypertension
# 9                                                  9%
# 10                                      85% (125/147)
# 11                                               -0.5
# 12  Significant reduction of sitting, supine, and ...
# 13                       -1.3 (study1), -1.4 (study2)
# 14                                               -0.7
#
#                                           study_group  \
# 0                                         venlafaxine
# 1   Duloxetine delayed-release capsules in Major D...
# 2                Clobetasol propionate shampoo, 0.05%
# 3   pemetrexed for injection plus cisplatin is com...
# 4                  a group given placebo in the trial
# 5                                          colchicine
# 6                                            VABOMERE
# 7      mesalamine suppositories (500 mg thrice daily)
# 8                                    Lisinopril group
# 9                                             Placebo
# 10        Azithromycin (500 mg once daily for 3 days)
# 11                  LEVEMIR + Liraglutide + Metformin
# 12                                             Adults
# 13       Tizanidine-treated group compared to placebo
# 14  doxylamine succinate and pyridoxine hydrochlor...
#
#                                            brand_name application_number  \
# 0                                         venlafaxine         ANDA090555
# 1                          Duloxetine Delayed-Release         ANDA203088
# 2                               clobetasol propionate         ANDA090974
# 3                                          Pemetrexed         ANDA204890
# 4                                           Cefoxitin         ANDA065415
# 5                                          Colchicine         ANDA204711
# 6                                            VABOMERE          NDA209776
# 7                                          Mesalamine         ANDA207448
# 8                                          LISINOPRIL         ANDA076180
# 9                                          Adalimumab          BLA761154
# 10                             Azithromycin Dihydrate         ANDA208250
# 11                                            LEVEMIR          BLA021536
# 12                                          Valsartan         ANDA204821
# 13                           Tizanidine Hydrochloride         ANDA078868
# 14  Doxylamine succinate and pyridoxine hydrochloride         ANDA205811
#
#                                      clinical_studies assessment  \
# 0   CLINICAL TRIALS The efficacy of venlafaxine hy...        Yes
# 1   14 CLINICAL STUDIES 14.1 Overview of the Clini...        Yes
# 2   14 CLINICAL STUDIES The safety and efficacy of...         No
# 3   14 CLINICAL STUDIES 14.1 Non-Squamous NSCLC In...        Yes
# 4   CLINICAL STUDIES A prospective, randomized, do...        Yes
# 5   14 CLINICAL STUDIES The evidence for the effic...         No
# 6   14 CLINICAL STUDIES 14.1 Complicated Urinary T...        Yes
# 7   14 CLINICAL STUDIES Two double-blind, placebo-...        Yes
# 8   14 CLINICAL STUDIES 14.1 Hypertension Two dose...         No
# 9   14 CLINICAL STUDIES 14.1 Rheumatoid Arthritis ...         No
# 10  14 CLINICAL STUDIES 14.1 Adult Patients Acute ...        Yes
# 11  14 CLINICAL STUDIES The efficacy and safety of...        Yes
# 12  14 CLINICAL STUDIES 14.1 Hypertension Adult Hy...        Yes
# 13  14 CLINICAL STUDIES Tizanidine’s capacity to r...         No
# 14  14 CLINICAL STUDIES A double-blind, randomized...        Yes
#
#                                                 notes
# 0   Correct but not specific: In these 5 studies, ...
# 1   After 13 weeks of treatment, patients taking D...
# 2                         Definition for success rate
# 3   Efficacy Parameter All Randomized and Treated ...
# 4   Endometritis occurred in 16/58 (27.6%) patient...
# 5                                         Nonsensical
# 6   Table 6: Clinical and Microbiological Response...
# 7   Correct but no clear attribution: Compared to ...
# 8                                      Not an outcome
# 9   Clinical remission is present and measured but...
# 10  For the 304 patients analyzed in the modified ...
# 11  Study H LEVEMIR + Liraglutide +Metformin Lirag...
# 12  Correct but no quantitative: Administration of...
# 13          -1.3 and -1.4 aren't anywhere in the text
# 14  Correct, but outcome needs more description ('...

# %% [markdown]
# Evaluate correctness

# %%
from IPython.display import clear_output
_start = 21
_current = _start

while _current <= len(df):

    clear_output(wait=True)
    print(f'{df["application_number"][_current]} \n')
    print(f'{df["study_group"][_current]}:\n {df["outcome"][_current]} -> {df["value"][_current]}\n')
    print(df["clinical_studies"][_current])

    assessment = input("Correct? (Yes/No): ")
    notes = input("Reason? (description): ")
    df.at[_current, 'assessment'] = assessment
    df.at[_current, 'notes'] = notes

    _current += 1

# %% [markdown]
# Save

# %%
# df.to_excel('20240607_mistralTrialEval.xlsx')

# %% [markdown]
# ### Trial 2: Mistral-7B-OpenOrca, Pydantic Class
# Load data

# %%
file_names = ['20240611_llm-orca-ner.xlsx','20240611_llm-orca-ner-set2.xlsx','20240611_llm-orca-ner-set3.xlsx']

df = pd.DataFrame()

for file in file_names:
    tdf = pd.read_excel(file).drop(labels='Unnamed: 0',axis=1)
    df = pd.concat([df,tdf]).reset_index(drop=True)

df
# Out:
#                                               outcome  \
# 0      Hamilton Depression Rating Scale (total score)
# 1                                                   4
# 2                                        Success rate
# 3                                   No Outcome Found.
# 4                             Median overall survival
# ..                                                ...
# 88               Risk of NSAID-induced mucosal injury
# 89                                   ulcer recurrence
# 90                            Objective response rate
# 91  Median time to alleviation of influenza signs ...
# 92                                          Mortality
#
#                                 value  \
# 0   significantly superior to placebo
# 1                                   2
# 2                               42.1%
# 3                                   ,
# 4                          9.0 months
# ..                                ...
# 88                             10–30%
# 89                                 4%
# 90                                80%
# 91                           1.5 days
# 92                                34%
#
#                                              regiment  \
# 0   venlafaxine hydrochloride in a range of 75 to ...
# 1                                               15523
# 2                Clobetasol propionate shampoo, 0.05%
# 3                                   No Regimen Found.
# 4                               triplet-therapy group
# ..                                                ...
# 88                                        misoprostol
# 89                        omeprazole + clarithromycin
# 90                                 LUNSUMIO treatment
# 91  Oseltamivir phosphate treatment of 2 mg per kg...
# 92                                 Carvedilol Tablets
#
#                     brand_name application_number  \
# 0                  venlafaxine         ANDA090555
# 1   Duloxetine Delayed-Release         ANDA203088
# 2        clobetasol propionate         ANDA090974
# 3                   Pemetrexed         ANDA204890
# 4                    Cefoxitin         ANDA065415
# ..                         ...                ...
# 88                     Cytotec          NDA019268
# 89                  Omeprazole         ANDA091672
# 90                    Lunsumio          BLA761263
# 91       Oseltamivir phosphate         ANDA208348
# 92                  Carvedilol         ANDA078384
#
#                                      clinical_studies
# 0   CLINICAL TRIALS The efficacy of venlafaxine hy...
# 1   14 CLINICAL STUDIES 14.1 Overview of the Clini...
# 2   14 CLINICAL STUDIES The safety and efficacy of...
# 3   14 CLINICAL STUDIES 14.1 Non-Squamous NSCLC In...
# 4   CLINICAL STUDIES A prospective, randomized, do...
# ..                                                ...
# 88  Clinical studies In a series of small short-te...
# 89  14 CLINICAL STUDIES 14.1 Active Duodenal Ulcer...
# 90  14 CLINICAL STUDIES The efficacy of LUNSUMIO w...
# 91  14 CLINICAL STUDIES 14.1 Treatment of Influenz...
# 92  14 CLINICAL STUDIES 14.1 Heart Failure A total...
#
# [93 rows x 6 columns]

# %% [markdown]
# Evaluate

# %%
from IPython.display import clear_output
_start = 33
_current = _start

while _current <= len(df):

    clear_output(wait=True)
    print(f'{df["application_number"][_current]} \n')
    print(f'{df["regiment"][_current]}:\n {df["outcome"][_current]} -> {df["value"][_current]}\n')
    print(df["clinical_studies"][_current])

    assessment = input("Correct? (Yes/No): ")
    notes = input("Reason? (description): ")
    df.at[_current, 'assessment'] = assessment
    df.at[_current, 'notes'] = notes

    _current += 1
# Out:
# ANDA078904
#
# nan:
#  Partial Onset Seizures Effectiveness in Partial Onset Seizures in Adults with Epilepsy -> levetiracetam as adjunctive therapy (added to other antiepileptic drugs) in adults was established in three multicenter, randomized, double-blind, placebo-controlled clinical studies in patients who had refractory partial onset seizures with or without secondary generalization.
#
# 14 CLINICAL STUDIES In the following studies, statistical significance versus placebo indicates a p value <0.05. 14.1 Partial Onset Seizures Effectiveness in Partial Onset Seizures in Adults with Epilepsy The effectiveness of levetiracetam as adjunctive therapy (added to other antiepileptic drugs) in adults was established in three multicenter, randomized, double-blind, placebo-controlled clinical studies in patients who had refractory partial onset seizures with or without secondary generalization. The tablet formulation was used in all these studies. In these studies, 904 patients were randomized to placebo, 1000 mg, 2000 mg, or 3000 mg/day. Patients enrolled in Study 1 or Study 2 had refractory partial onset seizures for at least two years and had taken two or more classical AEDs. Patients enrolled in Study 3 had refractory partial onset seizures for at least 1 year and had taken one classical AED. At the time of the study, patients were taking a stable dose regimen of at least one and could take a maximum of two AEDs. During the baseline period, patients had to have experienced at least two partial onset seizures during each 4-week period. Study 1 Study 1 was a double-blind, placebo-controlled, parallel-group study conducted at 41 sites in the United States comparing levetiracetam 1000 mg/day (N=97), levetiracetam 3000 mg/day (N=101), and placebo (N=95) given in equally divided doses twice daily. After a prospective baseline period of 12 weeks, patients were randomized to one of the three treatment groups described above. The 18-week treatment period consisted of a 6-week titration period, followed by a 12-week fixed dose evaluation period, during which concomitant AED regimens were held constant. The primary measure of effectiveness was a between group comparison of the percent reduction in weekly partial seizure frequency relative to placebo over the entire randomized treatment period (titration + evaluation period). Secondary outcome variables included the responder rate (incidence of patients with ≥50% reduction from baseline in partial onset seizure frequency). The results of the analysis of Study 1 are displayed in Table 10. Table 10: Reduction In Mean Over Placebo In Weekly Frequency Of Partial Onset Seizures In Study 1 Placebo(N=95) Levetiracetam 3000 mg/day (N=101) Levetiracetam1000 mg/day (N=97) Percent reduction in partial seizure frequency over placebo – 26.1%* 30.1%* *statistically significant versus placebo The percentage of patients (y-axis) who achieved ≥50% reduction in weekly seizure rates from baseline in partial onset seizure frequency over the entire randomized treatment period (titration + evaluation period) within the three treatment groups (x-axis) is presented in Figure 1. Figure 1: Responder Rate (≥50% Reduction From Baseline) In Study 1 *statistically significant versus placebo Study 2 Study 2 was a double-blind, placebo-controlled, crossover study conducted at 62 centers in Europe comparing levetiracetam 1000 mg/day (N=106), levetiracetam 2000 mg/day (N=105), and placebo (N=111) given in equally divided doses twice daily. The first period of the study (Period A) was designed to be analyzed as a parallel-group study. After a prospective baseline period of up to 12 weeks, patients were randomized to one of the three treatment groups described above. The 16-week treatment period consisted of the 4-week titration period followed by a 12-week fixed dose evaluation period, during which concomitant AED regimens were held constant. The primary measure of effectiveness was a between group comparison of the percent reduction in weekly partial seizure frequency relative to placebo over the entire randomized treatment period (titration + evaluation period). Secondary outcome variables included the responder rate (incidence of patients with ≥50% reduction from baseline in partial onset seizure frequency). The results of the analysis of Period A are displayed in Table 11. Table 11: Reduction In Mean Over Plac ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 12
#       9 print(f'{df["regiment"][_current]}:\n {df["outcome"][_current]} -> {df["value"][_current]}\n')
#      10 print(df["clinical_studies"][_current])
# ---> 12 assessment = input("Correct? (Yes/No): ")
#      13 notes = input("Reason? (description): ")
#      14 df.at[_current, 'assessment'] = assessment
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/.pyenv/versions/3.10.14/lib/python3.10/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Inspection Block
df = pd.read_excel('20240611_orcaTrialEval-inProgress.xlsx').drop(labels='Unnamed: 0',axis=1)

df[0:15]
# Out:
#                                               outcome  \
# 0      Hamilton Depression Rating Scale (total score)
# 1                                                   4
# 2                                        Success rate
# 3                                   No Outcome Found.
# 4                             Median overall survival
# 5                            Frequency of gout flares
# 6                            total treatment duration
# 7                                                 DAI
# 8                             Median overall survival
# 9                                                  .*
# 10                            Median overall survival
# 11                    HbA 1c reductions from baseline
# 12                                  Shoreline Erosion
# 13                                     Ashworth score
# 14  change from baseline in the Pregnancy Unique-Q...
#
#                                 value  \
# 0   significantly superior to placebo
# 1                                   2
# 2                               42.1%
# 3                                   ,
# 4                          9.0 months
# 5                           decreased
# 6                             10 days
# 7                                 78%
# 8                          9.0 months
# 9                                 NaN
# 10                         9.0 months
# 11                               -2.0
# 12                         2.7 meters
# 13                  Greater reduction
# 14                                0.7
#
#                                              regiment  \
# 0   venlafaxine hydrochloride in a range of 75 to ...
# 1                                               15523
# 2                Clobetasol propionate shampoo, 0.05%
# 3                                   No Regimen Found.
# 4                               triplet-therapy group
# 5                       colchicine 0.6 mg twice a day
# 6                                            VABOMERE
# 7   mesalamine suppositories 1000 mg once daily at...
# 8                               triplet-therapy group
# 9                        20 or 10 mg every other week
# 10                              triplet-therapy group
# 11                                twice-daily LEVEMIR
# 12    combined coastal protection and armoring method
# 13               Single oral doses of drug or placebo
# 14  doxylamine succinate and pyridoxine hydrochlor...
#
#                                            brand_name application_number  \
# 0                                         venlafaxine         ANDA090555
# 1                          Duloxetine Delayed-Release         ANDA203088
# 2                               clobetasol propionate         ANDA090974
# 3                                          Pemetrexed         ANDA204890
# 4                                           Cefoxitin         ANDA065415
# 5                                          Colchicine         ANDA204711
# 6                                            VABOMERE          NDA209776
# 7                                          Mesalamine         ANDA207448
# 8                                          LISINOPRIL         ANDA076180
# 9                                          Adalimumab          BLA761154
# 10                             Azithromycin Dihydrate         ANDA208250
# 11                                            LEVEMIR          BLA021536
# 12                                          Valsartan         ANDA204821
# 13                           Tizanidine Hydrochloride         ANDA078868
# 14  Doxylamine succinate and pyridoxine hydrochloride         ANDA205811
#
#                                      clinical_studies assessment  \
# 0   CLINICAL TRIALS The efficacy of venlafaxine hy...        Yes
# 1   14 CLINICAL STUDIES 14.1 Overview of the Clini...         No
# 2   14 CLINICAL STUDIES The safety and efficacy of...        Yes
# 3   14 CLINICAL STUDIES 14.1 Non-Squamous NSCLC In...         No
# 4   CLINICAL STUDIES A prospective, randomized, do...         No
# 5   14 CLINICAL STUDIES The evidence for the effic...        Yes
# 6   14 CLINICAL STUDIES 14.1 Complicated Urinary T...         No
# 7   14 CLINICAL STUDIES Two double-blind, placebo-...         No
# 8   14 CLINICAL STUDIES 14.1 Hypertension Two dose...         No
# 9   14 CLINICAL STUDIES 14.1 Rheumatoid Arthritis ...         No
# 10  14 CLINICAL STUDIES 14.1 Adult Patients Acute ...         No
# 11  14 CLINICAL STUDIES The efficacy and safety of...        Yes
# 12  14 CLINICAL STUDIES 14.1 Hypertension Adult Hy...         No
# 13  14 CLINICAL STUDIES Tizanidine’s capacity to r...        Yes
# 14  14 CLINICAL STUDIES A double-blind, randomized...        Yes
#
#                                                 notes
# 0   In these 5 studies, venlafaxine hydrochloride ...
# 1                                         nonsensical
# 2             Success Rate 1 at Endpoint 2 40 (42.1%)
# 3   The main efficacy outcome measures were OS and...
# 4                                 Example from prompt
# 5   In both trials, treatment with colchicine decr...
# 6   Study descriptor. Outcome should be: Clinical ...
# 7   Incorrect regiment: After 6 weeks of treatment...
# 8                                 Example from Prompt
# 9                                         Nonsensical
# 10                                Example from Prompt
# 11  Table 9: Type 2 Diabetes Mellitus – Adult Stud...
# 12                                        Nonsensical
# 13  Correct, but not much detail given: A statisti...
# 14  There was a 0.7 (95% confidence interval 0.2 t...

# %% [markdown]
# Save

# %%
# df.to_excel('20240611_orcaTrialEval-inProgress.xlsx')

# %% [markdown]
# Interestingly, OpenOrca would return back my original example to me at times

# %%
# Model didn't 'understand' and threw back the example?
print(f'{(12/93)*100}% returned example from prompt')
df[df['outcome']=='Median overall survival'].reset_index(drop=True)
# Out:
# 12.903225806451612% returned example from prompt
#                     outcome        value  \
# 0   Median overall survival   9.0 months
# 1   Median overall survival   9.0 months
# 2   Median overall survival   9.0 months
# 3   Median overall survival   9.0 months
# 4   Median overall survival   9.0 months
# 5   Median overall survival   9.0 months
# 6   Median overall survival   9.0 months
# 7   Median overall survival   9.0 months
# 8   Median overall survival   9.0 months
# 9   Median overall survival   9.0 months
# 10  Median overall survival  10.8 months
# 11  Median overall survival   9.0 months
# 12  Median overall survival   9.0 months
#
#                                              regiment  \
# 0                               triplet-therapy group
# 1                               triplet-therapy group
# 2                               triplet-therapy group
# 3                               triplet-therapy group
# 4                               triplet-therapy group
# 5                         metoprolol tartrate tablets
# 6                               triplet-therapy group
# 7                               triplet-therapy group
# 8                               triplet-therapy group
# 9                               triplet-therapy group
# 10  up to 90 days or 30 days beyond the day that C...
# 11                              triplet-therapy group
# 12                              triplet-therapy group
#
#                                     brand_name application_number  \
# 0                                    Cefoxitin         ANDA065415
# 1                                   LISINOPRIL         ANDA076180
# 2                       Azithromycin Dihydrate         ANDA208250
# 3                              Naproxen Sodium         ANDA212199
# 4                                   NURTEC ODT          NDA212728
# 5                          Metoprolol Tartrate         ANDA074644
# 6                     Benazepril Hydrochloride         ANDA078212
# 7   Nitrofurantoin (monohydrate/macrocrystals)         ANDA207372
# 8                                    NAGLAZYME          BLA125117
# 9                                  Clofarabine          NDA021673
# 10                                   Tretinoin         ANDA201687
# 11                          Rocuronium Bromide         ANDA216234
# 12                                   Ramelteon         ANDA212650
#
#                                      clinical_studies
# 0   CLINICAL STUDIES A prospective, randomized, do...
# 1   14 CLINICAL STUDIES 14.1 Hypertension Two dose...
# 2   14 CLINICAL STUDIES 14.1 Adult Patients Acute ...
# 3   14 CLINICAL STUDIES Naproxen has been studied ...
# 4   14 CLINICAL STUDIES 14.1 Acute Treatment of Mi...
# 5   14 CLINICAL STUDIES 14.1 Hypertension In contr...
# 6   14 CLINICAL STUDIES Hypertension Adult Patient...
# 7   CLINICAL STUDIES Controlled clinical trials co...
# 8   14 CLINICAL STUDIES A total of 56 patients wit...
# 9   14 CLINICAL STUDIES Seventy-eight (78) pediatr...
# 10  Clinical Studies Tretinoin capsules have been ...
# 11  14 CLINICAL STUDIES In U.S. clinical studies, ...
# 12  14 CLINICAL STUDIES 14.1 Controlled Clinical T...

# %% [markdown]
# ## Quantify and Compare Results
# Open the evaluation data from each trial set and compare the field expert assessed results against each other. Observe correctness and note any oddities across datasets.

# %%
# Trial 1, Mistral
mistral = pd.read_excel('20240607_mistralTrialEval.xlsx').drop(labels='Unnamed: 0',axis=1)

# Trial 2, Orca
orca = df = pd.read_excel('20240611_orcaTrialEval-inProgress.xlsx').drop(labels='Unnamed: 0',axis=1)

# %%
orca['assessment'][0:30].value_counts()
# Out:
# assessment
# No     16
# Yes    14
# Name: count, dtype: int64

# %%
mistral['assessment'].value_counts()
# Out:
# assessment
# Yes    16
# No     14
# Name: count, dtype: int64

# %%
orca['notes'].str.lower().value_counts()[0:2]
# Out:
# notes
# nonsensical            8
# example from prompt    5
# Name: count, dtype: int64

# %%
mistral['notes'].str.lower().value_counts()[0:1]
# Out:
# notes
# nonsensical    5
# Name: count, dtype: int64

# %% [markdown]
# <u>**Manual Assessment**</u>:
# Mistral -> 16 Right, 14 Wrong but 5 of those were nonsensical, leaving 9 factually wrong
# Orca -> 14 Right, 16 Wrong but 5 of those were directly from the prompt, 8 were nonsensical, leaving 3 factually wrong
#
# <u>**Runtime (Local)**</u>:
# Mistral -> 100%|██████████| 30/30 [47:30:21<00:00, 5700.73s/it]
# Orca -> 100%|██████████| 32/32 [36:24:09<00:00, 4095.31s/it]
#
# Both methods of prompting/enforcing schema ended up about the same from this tiny sample of 30 replicates. The Orca trial ran faster (4095.31s per it vs 5700.73 s per IT) though both took a significant time to run. Notably, Orca has less responses that were factually incorrect or made up than Mistral. At times, Orca would spit out the exact sample from the prompt. One of the factually wrong response from Orca was simply "No Outcomes Found", which was incorrect as there were many outcomes.
#
# It is also worth noting that each of these prompts produced exactly one outcome despite each clinical trial sections commonly having many outcomes. This could potentially be overcome by specifying an array of dictionaries as the output in the schema definition rather than just a single dictionary.
